# %% [markdown]
# # APIs for data retrieval

# %% [markdown]
# An Application Programming Interface, commonly known as API, is a set of protocols, routines, and tools for building software applications. APIs allow different software systems to communicate with each other and exchange data in a standardized and efficient way.
#
# APIs for retrieving data enable developers to access and extract information from various sources such as databases, web services, or applications. These APIs often provide a structured and consistent way of accessing data, making it easier for developers to consume and use the data in their applications.
#
# APIs for retrieving data can be used for a variety of purposes, such as gathering information for business intelligence, analyzing user behavior, or integrating data from different sources into a single application. These APIs often use standardized data formats, such as JSON or XML, to ensure compatibility and interoperability between different systems.
#
# As the amount of data available online continues to grow, APIs for retrieving data have become an essential tool for developers to access and analyze this data. By leveraging these APIs, developers can quickly and easily retrieve the data they need, without having to manually extract and process it themselves.

# %% [markdown]
# ### API types
# There are several types of APIs available, but two of the most commonly used types are REST API and HTTP API.
#
# - REST API (Representational State Transfer API):
# REST stands for Representational State Transfer, and it's a set of architectural principles for building web services. A REST API is a type of web service that follows the REST architecture principles. REST APIs use HTTP methods (GET, POST, PUT, DELETE, etc.) to access and manipulate resources, which are identified by URIs (Uniform Resource Identifiers). REST APIs typically return data in JSON or XML format and are widely used for building web and mobile applications.
#
#
# - HTTP API (Hypertext Transfer Protocol API):
# HTTP stands for Hypertext Transfer Protocol, which is the protocol used for transferring data over the World Wide Web. An HTTP API is a type of web service that uses HTTP methods to access and manipulate resources. An HTTP API can be RESTful, but it doesn't have to be. HTTP APIs are often used for simple operations like CRUD (Create, Read, Update, Delete) on resources and return data in JSON or XML format.
#
#
# Other types of APIs include SOAP (Simple Object Access Protocol), GraphQL, and WebSockets. SOAP is an older protocol used for building web services, while GraphQL is a newer API technology that allows clients to specify the data they need and receive it in a single request. WebSockets are used for real-time, two-way communication between a client and a server.

# %% [markdown]
# ### python and APIs

# %% [markdown]
# Python is a popular programming language that provides powerful tools for interacting with APIs. Here are the steps to interact with APIs using Python:
#
# 1. Import the necessary libraries: Python has several libraries that make it easy to interact with APIs, including requests, json, and urllib. Before making any API requests, you need to import the appropriate libraries.
#
# 2. Find the API endpoint: The endpoint is the URL that you will use to send your API requests. It's essential to understand the API documentation to find the correct endpoint for the specific data you want to retrieve.
#
# 3. Send a request: Once you have the endpoint, you can use Python's requests library to send an HTTP request to the API endpoint. The requests library has several methods for sending different types of HTTP requests, including GET, POST, PUT, DELETE, and more.
#
# 4. Parse the response: The API response will typically be in JSON format. Python's json library can be used to parse the JSON data and convert it into a Python dictionary that you can easily work with in your code.
#
# 5. Extract the data: Once you have the API response in a Python dictionary, you can extract the data you need and use it in your application.
#
# Python's ease of use and powerful libraries make it an excellent language for interacting with APIs. With just a few lines of code, you can send requests to APIs, parse the response data, and extract the information you need to build powerful applications.

# %% [markdown]
# ### Using the request package

# %% [markdown]
# To do this, we need to know how to send requests first. We will use an amazing package called [`requests`](http://docs.python-requests.org/en/master/). If you do not have it installed, please install it using e.g. `pip` (in your command prompt or terminal):
#
#
# ```$ pip install requests```

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests # library for making HTTP requests
import pandas as pd # library for data analysis
import datetime as dt # library for handling date and time objects

# %% [markdown]
# ###### open DMI weather data
#
# Go to the [documentation](https://confluence.govcloud.dk/display/FDAPI/Danish+Meteorological+Institute+-+Open+Data)
#
# Using weather as an example, we should first know what is the request URL (where the request goes to), with what parameters(e.g., API key and stationID). In our case, we know that our API key and the stationId to query so we can do the following.
#
# You will have to create a user and retrieve an API key for the API you want to use [how to](https://confluence.govcloud.dk/display/FDAPI/User+Creation)
#
# I have saved my API key in an file ```.env```
#
#     api_key = your_api_key
#
# Specifically we will look at [Meteorological Observation](https://confluence.govcloud.dk/display/FDAPI/Meteorological+Observation)

# %%
my_dict = {}

with open(r"/Users/christianhellum/Cand. Merc./Data-Science-Project/data_science_project/.env", "r") as f:
    for line in f:
        key, val = line.split('=')
        my_dict[key.strip()] = val.strip()

# %%
headers = my_dict
print(headers)
# Out:
# {'X-RapidAPI-Key': 'c795ba9581msh07d0178516af21bp1d788bjsnd4de235dbca6', 'X-RapidAPI-Host': 'sky-scrapper.p.rapidapi.com'}

# %%
querystring = {"hotelId":"106005202","entityId":"27537542","checkin":"2024-04-13","checkout":"2024-04-20","adults":"2","rooms":"1","currency":"USD","market":"en-US","countryCode":"US"}

# %%
url = "https://sky-scrapper.p.rapidapi.com/api/v1/hotels/getHotelPrices"
r = requests.get(url, headers=headers, params=querystring) # Issues a HTTP GET request
r.url # `requests` help us encode the URL in the correct format
# Out:
# 'https://sky-scrapper.p.rapidapi.com/api/v1/hotels/getHotelPrices?hotelId=106005202&entityId=27537542&checkin=2024-04-13&checkout=2024-04-20&adults=2&rooms=1&currency=USD&market=en-US&countryCode=US'

# %%
r.status_code # 200 means success
# Out:
# 200

# %%
hotel = r.json()
hotel
# Out:
# {'status': True,
#  'timestamp': 1712560010960,
#  'data': {'metaInfo': {'ratesCta': 'Go to site',
#    'rates': [{'partnerName': 'SuperTravel',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_11.png',
#      'partnerId': 'h_11',
#      'roomType': 'Double room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_11/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=926482&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1235.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJiOWU3ZmQwNjRjMTA5YzUwZDQ5OWZlOTMyOWQ4OTk5ZSJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnN1cGVyLmNvbS90cmF2ZWwvdHJhbnNpdGlvbi8%...&max_price=2543.0&channel=iphone',
#      'rawPrice': 176,
#      'rawPriceGbp': 140,
#      'price': '$176',
#      'rateBriefFeatures': ['Meals not included',
#       'Non-Refundable',
#       'Double room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 34},
#     {'partnerName': 'Prestigia',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_pi.png',
#      'partnerId': 'h_pi',
#      'roomType': 'Double room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pi/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=75&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1426.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICIyNjVkMDZkOGJmMmY4NjY3MmNiOTA4NzNhNGJkMmRjMiJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnByZXN0aWdpYS5jb20vZW4vcHJvZHVpdC5waHA%...%3D%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 204,
#      'rawPriceGbp': 161,
#      'price': '$204',
#      'rateBriefFeatures': ['Meals not included',
#       'Non-Refundable',
#       'Double room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 33},
#     {'partnerName': 'Expedia',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_xp.png',
#      'partnerId': 'h_xp',
#      'roomType': 'Room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_xp/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=1&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 31},
#     {'partnerName': 'Hotels.com',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_hc.png',
#      'partnerId': 'h_hc',
#      'roomType': 'Room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_hc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=17&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 30},
#     {'partnerName': 'Travelocity',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_tc.png',
#      'partnerId': 'h_tc',
#      'roomType': 'Room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_tc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927567&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJkODViNzFjYThiYmQ5MmRjNTBiZmRhZWIwMzU5NGRjNyJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnRyYXZlbG9jaXR5LmNvbS9Ib3RlbC1TZWFyY2g%%3D%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 29},
#     {'partnerName': 'ZenHotels',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_zh.png',
#      'partnerId': 'h_zh',
#      'roomType': 'Room',
#      'roomPolicies': 'Room Only, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_zh/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927794&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Room Only', 'Non-Refundable', 'Room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 28},
#     {'partnerName': 'Priceline',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_pr.png',
#      'partnerId': 'h_pr',
#      'roomType': 'Room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pr/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=151&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 27},
#     {'partnerName': 'Edreams',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_ei.png',
#      'partnerId': 'h_ei',
#      'roomType': 'Double room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_ei/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927018&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Meals not included',
#       'Non-Refundable',
#       'Double room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 26},
#     {'partnerName': 'Booking.com',
#      'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_bc.png',
#      'partnerId': 'h_bc',
#      'roomType': 'Double room',
#      'roomPolicies': 'Meals not included, Non-Refundable',
#      'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_bc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=13&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone',
#      'rawPrice': 228,
#      'rawPriceGbp': 180,
#      'price': '$228',
#      'rateBriefFeatures': ['Meals not included',
#       'Non-Refundable',
#       'Double room'],
#      'isOfficial': False,
#      'isShowHotelName': False,
#      'score': 25}]},
#   'roomTypes': [{'name': 'Run Of House - Room Selected At Check In',
#     'sizeString': None,
#     'amenities': [{'key': 'WifiService', 'icon': 'wifi', 'value': 'WiFi'},
#      {'key': 'Shower', 'icon': 'onsen', 'value': 'Shower'},
#      {'key': 'AirConditioning', 'icon': 'aircon', 'value': 'Air conditioning'},
#      {'key': 'HotWater24Hours',
#       'icon': 'beer',
#       'value': 'Hot water (24 hours)'},
#      {'key': 'Television', 'icon': 'media', 'value': 'Television'}],
#     'size': None,
#     'baseRoomBedsString': ['Bed type confirmed at check-in'],
#     'id': '14018960',
#     'photos': [{'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '14018960',
#       'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#       'fromPartner': 'From Trip.com'}],
#     'floors': None,
#     'rateGroups': [{'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'}],
#       'rates': [{'acceptedCards': [{'code': 'visa', 'name': 'Visa'},
#          {'code': 'master-card', 'name': 'Mastercard'},
#          {'code': 'american-express', 'name': 'American Express'},
#          {'code': 'jcb', 'name': 'JCB'},
#          {'code': 'unionpay', 'name': 'UnionPay'},
#          {'code': 'diners-club', 'name': 'Diners Club'},
#          {'code': 'discover', 'name': 'Discover'}],
#         'cancellationPolicy': "If you cancel, you'll be charged for 1 night of your stay.",
#         'cancellationPolicyShortDescription': "If you cancel, you'll be charged for 1 night of your stay",
#         'freeMessageForRefundable': None,
#         'href': {'adults': 2,
#          'partnerRef': 'd_ct',
#          'paymentType': 'Prepaid',
#          'rateRef': '1703526_1516523597_0_2_1516523597_0_PP',
#          'rooms': 1,
#          'roomRef': '14018960',
#          'partnerPrice': 2157.94,
#          'checkin': '2024-04-13',
#          'version': 2,
#          'instantConfirmation': True,
#          'checkout': '2024-04-20',
#          'partnerCurrency': 'USD'},
#         'hrefHash': 'd0103ef58a2c662a65651296ed8dbe97164d1bafabc9887ec785ef8c87263b050c6e9a6aac51d17c3a6dc30385e510ea9802fce0039b792db69b5d0d6a2efa88',
#         'rateName': 'Option 1',
#         'price': {'rawTotal': 1593,
#          'total': '$1,593',
#          'totalWithTaxes': '$2,157.94',
#          'rawTotalWithTaxes': 2157.94,
#          'baseTotal': '$1,593.21',
#          'rawBaseTotal': 1593.21,
#          'perNight': '$228',
#          'perNightBreakdown': '($227.57 per night)',
#          'surcharges': {'title': 'Taxes & Fees',
#           'rawTotalTaxes': 564.73,
#           'totalTaxes': '$564.73',
#           'content': [{'name': 'Other', 'amount': '$234.96'},
#            {'name': 'City Tax', 'amount': '$24.50'},
#            {'name': 'Resort Fee', 'amount': '$305.27'}]},
#          'daily': None,
#          'paymentScheduleBreakdown': {'payNow': {'text': '$2,157.94',
#            'info': None,
#            'baselineDelta': 'neutral',
#            'color': 'rgb(17,18,54)'},
#           'payOnArrival': None,
#           'totalWithTaxes': '$2,157.94'}},
#         'rateFeatures': [{'title': 'Instant confirmation',
#           'baselineDelta': 'positive',
#           'key': 'confirmationType',
#           'value': '0',
#           'icon': 'time',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Your booking will be confirmed immediately by {Partner}. You'll immediately receive a confirmation email."}]},
#          {'title': 'Confirmed at check-in',
#           'baselineDelta': 'warning',
#           'key': 'bedType',
#           'value': '1_RUNOFHOUSE',
#           'icon': 'hotels',
#           'color': 'rgb(255,148,0)'},
#          {'title': 'Up to 2 guests',
#           'baselineDelta': 'neutral',
#           'key': 'maxOccupancy',
#           'value': '2',
#           'icon': 'adult',
#           'color': 'rgb(17,18,54)'},
#          {'title': 'Meals not included',
#           'baselineDelta': 'neutral',
#           'key': 'mealPlan',
#           'value': 'room_only',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)',
#           'descriptions': None},
#          {'title': 'Pay now',
#           'baselineDelta': 'neutral',
#           'key': 'paymentPolicy',
#           'value': 'Prepaid',
#           'icon': 'paid',
#           'color': 'rgb(17,18,54)'},
#          {'title': 'Partially refundable',
#           'baselineDelta': 'neutral',
#           'key': 'cancellationPolicy',
#           'value': 'partially_refundable',
#           'icon': 'tick',
#           'color': 'rgb(17,18,54)',
#           'descriptions': [{'text': "If you cancel, you'll be charged for 1 night of your stay."}]},
#          {'title': 'Non-smoking',
#           'baselineDelta': 'neutral',
#           'key': 'smoking',
#           'value': 'NonSmoking',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)'}],
#         'stickySummary': 'Run Of House - Room Selected At Check In, Option 1, Meals not included, Refundable',
#         'partner': {'name': 'Trip.com',
#          'partnerId': 'd_ct',
#          'logo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#          'isOfficial': False},
#         'roomName': 'Run Of House - Room Selected At Check In',
#         'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#           'partnerName': 'Trip.com',
#           'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#           'partnerId': 'd_ct',
#           'fromPartner': 'From Trip.com'}],
#         'cugDeal': None,
#         'couponDeal': None,
#         'commendatoryFlag': 'option_roomOnly',
#         'offerType': 'dbook',
#         'unconfirmedErrorMessage': "If you don't receive an email from Trip.com within an hour, please contact them directly to confirm the exact status of your booking.",
#         'roomId': '14018960',
#         'baseRoomId': '14018960',
#         'bookingData': 'eyJjb3N0Ijp7ImRpc3BsYXlQcmljZSI6eyJwYXJ0bmVyIjoxNTkzLjIxLCJ0cmF2ZWxsZXIiOjE1OTMuMjF9LCJ0b3RhbFdpdGhUYXgiOnsicGFydG5lciI6MjE1Ny45NCwidHJhdmVsbGVyIjoyMTU3Ljk0fX0sInJlcUpxZENsb3NlZFVzZXJHcm91cCI6W10sIm11bHRpUGVyc29uQWR1bHRzIjowfQ==',
#         'benefits': None,
#         'priceIncludes': None,
#         'bedsString': 'Bed type confirmed at check-in',
#         'extraBed': None,
#         'creditCardText': None,
#         'paymentCode': 'uaBlcUut37fCmhplSoIPVZkxgvA+wMFD8PeP1SSoYUwnVTXnSVbE7lp1UqSi3jAZvki2Ba3SOER3Ehsx1vm+SA==',
#         'trackingId': '100020771-20240408150645-942d153175444ea9894fdde06a1b39c0',
#         'score': 32}],
#       'cheapestPrice': 1593,
#       'commendatoryValues': ['Room Only'],
#       'commendatoryFlag': 'option_roomOnly'},
#      {'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'}],
#       'rates': [{'acceptedCards': [{'code': 'visa', 'name': 'Visa'},
#          {'code': 'master-card', 'name': 'Mastercard'},
#          {'code': 'american-express', 'name': 'American Express'},
#          {'code': 'jcb', 'name': 'JCB'},
#          {'code': 'unionpay', 'name': 'UnionPay'},
#          {'code': 'diners-club', 'name': 'Diners Club'},
#          {'code': 'discover', 'name': 'Discover'}],
#         'cancellationPolicy': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night.",
#         'cancellationPolicyShortDescription': 'Free cancellation before 4:00 PM on Apr 11, 2024',
#         'guaranteePolicy': {'description': 'A deposit for 1 night is due when you book.',
#          'depositAmount': '$436.11'},
#         'freeMessageForRefundable': None,
#         'href': {'adults': 2,
#          'partnerRef': 'd_ct',
#          'paymentType': 'PayOnArrival',
#          'rateRef': '1703526_1516525967_0_2_1516525967_0_FG',
#          'rooms': 1,
#          'roomRef': '14018960',
#          'partnerPrice': 2593.78,
#          'checkin': '2024-04-13',
#          'version': 2,
#          'instantConfirmation': True,
#          'checkout': '2024-04-20',
#          'partnerCurrency': 'USD'},
#         'hrefHash': 'ba5cc3af8613227a2d706aa1bcff51758edf1c3c40eb7982099dca830c2719be4389f953eb4203c369f6f97738f52f02346b91f023f0c916b244f55a2e91a313',
#         'rateName': 'Option 2',
#         'price': {'rawTotal': 1973,
#          'total': '$1,973',
#          'totalWithTaxes': '$2,593.78',
#          'rawTotalWithTaxes': 2593.78,
#          'baseTotal': '$1,972.98',
#          'rawBaseTotal': 1972.98,
#          'perNight': '$282',
#          'perNightBreakdown': '($281.86 per night)',
#          'surcharges': {'title': 'Taxes & Fees',
#           'rawTotalTaxes': 620.8,
#           'totalTaxes': '$620.80',
#           'content': [{'name': 'Other', 'amount': '$291.03'},
#            {'name': 'City Tax', 'amount': '$24.50'},
#            {'name': 'Resort Fee', 'amount': '$305.27'}]},
#          'daily': None,
#          'paymentScheduleBreakdown': {'payNow': None,
#           'payOnArrival': {'text': '$2,593.78',
#            'info': None,
#            'baselineDelta': 'positive',
#            'color': 'rgb(0,166,152)'},
#           'totalWithTaxes': '$2,593.78'}},
#         'rateFeatures': [{'title': 'Instant confirmation',
#           'baselineDelta': 'positive',
#           'key': 'confirmationType',
#           'value': '0',
#           'icon': 'time',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Your booking will be confirmed immediately by {Partner}. You'll immediately receive a confirmation email."}]},
#          {'title': 'Confirmed at check-in',
#           'baselineDelta': 'warning',
#           'key': 'bedType',
#           'value': '1_RUNOFHOUSE',
#           'icon': 'hotels',
#           'color': 'rgb(255,148,0)'},
#          {'title': 'Up to 2 guests',
#           'baselineDelta': 'neutral',
#           'key': 'maxOccupancy',
#           'value': '2',
#           'icon': 'adult',
#           'color': 'rgb(17,18,54)'},
#          {'title': 'Meals not included',
#           'baselineDelta': 'neutral',
#           'key': 'mealPlan',
#           'value': 'room_only',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)',
#           'descriptions': None},
#          {'title': 'Pay on arrival',
#           'baselineDelta': 'positive',
#           'key': 'paymentPolicy',
#           'value': 'PayOnArrival',
#           'icon': 'paid',
#           'color': 'rgb(0,166,152)'},
#          {'title': 'Free cancellation',
#           'baselineDelta': 'positive',
#           'key': 'cancellationPolicy',
#           'value': 'refundable',
#           'icon': 'tick',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night."}]},
#          {'title': 'Non-smoking',
#           'baselineDelta': 'neutral',
#           'key': 'smoking',
#           'value': 'NonSmoking',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)'}],
#         'stickySummary': 'Run Of House - Room Selected At Check In, Option 2, Meals not included, Refundable',
#         'partner': {'name': 'Trip.com',
#          'partnerId': 'd_ct',
#          'logo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#          'isOfficial': False},
#         'roomName': 'Run Of House - Room Selected At Check In',
#         'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#           'partnerName': 'Trip.com',
#           'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#           'partnerId': 'd_ct',
#           'fromPartner': 'From Trip.com'}],
#         'cugDeal': None,
#         'couponDeal': None,
#         'commendatoryFlag': 'option_free_cancellation_pay_on_arrival',
#         'offerType': 'dbook',
#         'unconfirmedErrorMessage': "If you don't receive an email from Trip.com within an hour, please contact them directly to confirm the exact status of your booking.",
#         'roomId': '14018960',
#         'baseRoomId': '14018960',
#         'bookingData': 'eyJjb3N0Ijp7ImRpc3BsYXlQcmljZSI6eyJwYXJ0bmVyIjoxOTcyLjk4LCJ0cmF2ZWxsZXIiOjE5NzIuOTh9LCJ0b3RhbFdpdGhUYXgiOnsicGFydG5lciI6MjU5My43OCwidHJhdmVsbGVyIjoyNTkzLjc4fX0sInJlcUpxZENsb3NlZFVzZXJHcm91cCI6W10sIm11bHRpUGVyc29uQWR1bHRzIjowfQ==',
#         'benefits': None,
#         'priceIncludes': None,
#         'bedsString': 'Bed type confirmed at check-in',
#         'extraBed': None,
#         'creditCardText': None,
#         'paymentCode': 'uaBlcUut37fCmhplSoIPVZ1RvqBKjH/qRmaOsySfBN1GM4zDqaGiRhwTrjwVTQx2Kpykn0hClZfWSfpmPaDAGg==',
#         'trackingId': '100020771-20240408150645-942d153175444ea9894fdde06a1b39c0',
#         'score': 23}],
#       'cheapestPrice': 1973,
#       'commendatoryValues': ['Free cancellation', 'Pay on arrival'],
#       'commendatoryFlag': 'option_free_cancellation_pay_on_arrival'},
#      {'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'}],
#       'rates': [{'acceptedCards': [{'code': 'visa', 'name': 'Visa'},
#          {'code': 'master-card', 'name': 'Mastercard'},
#          {'code': 'american-express', 'name': 'American Express'},
#          {'code': 'jcb', 'name': 'JCB'},
#          {'code': 'unionpay', 'name': 'UnionPay'},
#          {'code': 'diners-club', 'name': 'Diners Club'},
#          {'code': 'discover', 'name': 'Discover'}],
#         'cancellationPolicy': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night.",
#         'cancellationPolicyShortDescription': 'Free cancellation before 4:00 PM on Apr 11, 2024',
#         'freeMessageForRefundable': None,
#         'href': {'adults': 2,
#          'partnerRef': 'd_ct',
#          'paymentType': 'Prepaid',
#          'rateRef': '1703526_1516523363_0_2_1516523363_0_PP',
#          'rooms': 1,
#          'roomRef': '14018960',
#          'partnerPrice': 2593.78,
#          'checkin': '2024-04-13',
#          'version': 2,
#          'instantConfirmation': True,
#          'checkout': '2024-04-20',
#          'partnerCurrency': 'USD'},
#         'hrefHash': '0960c6535522da7fdeeed47a09c846087329915f64c7df09ed31505bc074aed51b6f5a945c042675cbc07e7f6e75196d49faded856dd6f43a143294ad8e4b0d4',
#         'rateName': 'Option 3',
#         'price': {'rawTotal': 1973,
#          'total': '$1,973',
#          'totalWithTaxes': '$2,593.78',
#          'rawTotalWithTaxes': 2593.78,
#          'baseTotal': '$1,972.98',
#          'rawBaseTotal': 1972.98,
#          'perNight': '$282',
#          'perNightBreakdown': '($281.86 per night)',
#          'surcharges': {'title': 'Taxes & Fees',
#           'rawTotalTaxes': 620.8,
#           'totalTaxes': '$620.80',
#           'content': [{'name': 'Other', 'amount': '$291.03'},
#            {'name': 'City Tax', 'amount': '$24.50'},
#            {'name': 'Resort Fee', 'amount': '$305.27'}]},
#          'daily': None,
#          'paymentScheduleBreakdown': {'payNow': {'text': '$2,593.78',
#            'info': None,
#            'baselineDelta': 'neutral',
#            'color': 'rgb(17,18,54)'},
#           'payOnArrival': None,
#           'totalWithTaxes': '$2,593.78'}},
#         'rateFeatures': [{'title': 'Instant confirmation',
#           'baselineDelta': 'positive',
#           'key': 'confirmationType',
#           'value': '0',
#           'icon': 'time',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Your booking will be confirmed immediately by {Partner}. You'll immediately receive a confirmation email."}]},
#          {'title': 'Confirmed at check-in',
#           'baselineDelta': 'warning',
#           'key': 'bedType',
#           'value': '1_RUNOFHOUSE',
#           'icon': 'hotels',
#           'color': 'rgb(255,148,0)'},
#          {'title': 'Up to 2 guests',
#           'baselineDelta': 'neutral',
#           'key': 'maxOccupancy',
#           'value': '2',
#           'icon': 'adult',
#           'color': 'rgb(17,18,54)'},
#          {'title': 'Meals not included',
#           'baselineDelta': 'neutral',
#           'key': 'mealPlan',
#           'value': 'room_only',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)',
#           'descriptions': None},
#          {'title': 'Pay now',
#           'baselineDelta': 'neutral',
#           'key': 'paymentPolicy',
#           'value': 'Prepaid',
#           'icon': 'paid',
#           'color': 'rgb(17,18,54)'},
#          {'title': 'Free cancellation',
#           'baselineDelta': 'positive',
#           'key': 'cancellationPolicy',
#           'value': 'refundable',
#           'icon': 'tick',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night."}]},
#          {'title': 'Non-smoking',
#           'baselineDelta': 'neutral',
#           'key': 'smoking',
#           'value': 'NonSmoking',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)'}],
#         'stickySummary': 'Run Of House - Room Selected At Check In, Option 3, Meals not included, Refundable',
#         'partner': {'name': 'Trip.com',
#          'partnerId': 'd_ct',
#          'logo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#          'isOfficial': False},
#         'roomName': 'Run Of House - Room Selected At Check In',
#         'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#           'partnerName': 'Trip.com',
#           'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#           'partnerId': 'd_ct',
#           'fromPartner': 'From Trip.com'}],
#         'cugDeal': None,
#         'couponDeal': None,
#         'commendatoryFlag': 'option_free_cancellation',
#         'offerType': 'dbook',
#         'unconfirmedErrorMessage': "If you don't receive an email from Trip.com within an hour, please contact them directly to confirm the exact status of your booking.",
#         'roomId': '14018960',
#         'baseRoomId': '14018960',
#         'bookingData': 'eyJjb3N0Ijp7ImRpc3BsYXlQcmljZSI6eyJwYXJ0bmVyIjoxOTcyLjk4LCJ0cmF2ZWxsZXIiOjE5NzIuOTh9LCJ0b3RhbFdpdGhUYXgiOnsicGFydG5lciI6MjU5My43OCwidHJhdmVsbGVyIjoyNTkzLjc4fX0sInJlcUpxZENsb3NlZFVzZXJHcm91cCI6W10sIm11bHRpUGVyc29uQWR1bHRzIjowfQ==',
#         'benefits': None,
#         'priceIncludes': None,
#         'bedsString': 'Bed type confirmed at check-in',
#         'extraBed': None,
#         'creditCardText': None,
#         'paymentCode': 'uaBlcUut37fCmhplSoIPVVJE7X843eZrfUKkl69x6vSK3FedW6YUHvEaRlBAHSYJKGPO/2P/hf6dmNFrP+x3kQ==',
#         'trackingId': '100020771-20240408150645-942d153175444ea9894fdde06a1b39c0',
#         'score': 22}],
#       'cheapestPrice': 1973,
#       'commendatoryValues': ['Free cancellation'],
#       'commendatoryFlag': 'option_free_cancellation'},
#      {'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'}],
#       'rates': [{'acceptedCards': [{'code': 'visa', 'name': 'Visa'},
#          {'code': 'master-card', 'name': 'Mastercard'},
#          {'code': 'american-express', 'name': 'American Express'},
#          {'code': 'jcb', 'name': 'JCB'},
#          {'code': 'unionpay', 'name': 'UnionPay'},
#          {'code': 'diners-club', 'name': 'Diners Club'},
#          {'code': 'discover', 'name': 'Discover'}],
#         'cancellationPolicy': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night.",
#         'cancellationPolicyShortDescription': 'Free cancellation before 4:00 PM on Apr 11, 2024',
#         'guaranteePolicy': {'description': 'A deposit for 1 night is due when you book.',
#          'depositAmount': '$493.49'},
#         'freeMessageForRefundable': None,
#         'href': {'adults': 2,
#          'partnerRef': 'd_ct',
#          'paymentType': 'PayOnArrival',
#          'rateRef': '1703526_1516521195_0_2_1516521195_0_FG',
#          'rooms': 1,
#          'roomRef': '14018960',
#          'partnerPrice': 2880.67,
#          'checkin': '2024-04-13',
#          'version': 2,
#          'instantConfirmation': True,
#          'checkout': '2024-04-20',
#          'partnerCurrency': 'USD'},
#         'hrefHash': 'cb1bef9c2c23cafeaf2aeee0f2411152b30b04d292dfd0490cd4acca133526282a52646fc5d774da79d4f21b668a061b2c7ace77d91507689d9cb7bddf7e3f8d',
#         'rateName': 'Option 4',
#         'price': {'rawTotal': 2223,
#          'total': '$2,223',
#          'totalWithTaxes': '$2,880.67',
#          'rawTotalWithTaxes': 2880.67,
#          'baseTotal': '$2,223.01',
#          'rawBaseTotal': 2223.01,
#          'perNight': '$318',
#          'perNightBreakdown': '($317.57 per night)',
#          'surcharges': {'title': 'Taxes & Fees',
#           'rawTotalTaxes': 657.66,
#           'totalTaxes': '$657.66',
#           'content': [{'name': 'Other', 'amount': '$327.89'},
#            {'name': 'City Tax', 'amount': '$24.50'},
#            {'name': 'Resort Fee', 'amount': '$305.27'}]},
#          'daily': None,
#          'paymentScheduleBreakdown': {'payNow': None,
#           'payOnArrival': {'text': '$2,880.67',
#            'info': None,
#            'baselineDelta': 'positive',
#            'color': 'rgb(0,166,152)'},
#           'totalWithTaxes': '$2,880.67'}},
#         'rateFeatures': [{'title': 'Instant confirmation',
#           'baselineDelta': 'positive',
#           'key': 'confirmationType',
#           'value': '0',
#           'icon': 'time',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Your booking will be confirmed immediately by {Partner}. You'll immediately receive a confirmation email."}]},
#          {'title': 'Confirmed at check-in',
#           'baselineDelta': 'warning',
#           'key': 'bedType',
#           'value': '1_RUNOFHOUSE',
#           'icon': 'hotels',
#           'color': 'rgb(255,148,0)'},
#          {'title': 'Up to 2 guests',
#           'baselineDelta': 'neutral',
#           'key': 'maxOccupancy',
#           'value': '2',
#           'icon': 'adult',
#           'color': 'rgb(17,18,54)'},
#          {'title': '2x breakfast',
#           'baselineDelta': 'positive',
#           'key': 'mealPlan',
#           'value': 'breakfast_included',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': 'Meals not included',
#             'date': '2024-04-13'},
#            {'text': '2x breakfast', 'date': '2024-04-14'},
#            {'text': '2x breakfast', 'date': '2024-04-15'},
#            {'text': '2x breakfast', 'date': '2024-04-16'},
#            {'text': '2x breakfast', 'date': '2024-04-17'},
#            {'text': '2x breakfast', 'date': '2024-04-18'},
#            {'text': '2x breakfast', 'date': '2024-04-19'},
#            {'text': '2x breakfast', 'date': '2024-04-20'}]},
#          {'title': 'Pay on arrival',
#           'baselineDelta': 'positive',
#           'key': 'paymentPolicy',
#           'value': 'PayOnArrival',
#           'icon': 'paid',
#           'color': 'rgb(0,166,152)'},
#          {'title': 'Free cancellation',
#           'baselineDelta': 'positive',
#           'key': 'cancellationPolicy',
#           'value': 'refundable',
#           'icon': 'tick',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night."}]},
#          {'title': 'Non-smoking',
#           'baselineDelta': 'neutral',
#           'key': 'smoking',
#           'value': 'NonSmoking',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)'}],
#         'stickySummary': 'Run Of House - Room Selected At Check In, Option 4, 2x breakfast, Refundable',
#         'partner': {'name': 'Trip.com',
#          'partnerId': 'd_ct',
#          'logo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#          'isOfficial': False},
#         'roomName': 'Run Of House - Room Selected At Check In',
#         'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#           'partnerName': 'Trip.com',
#           'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#           'partnerId': 'd_ct',
#           'fromPartner': 'From Trip.com'}],
#         'cugDeal': None,
#         'couponDeal': None,
#         'commendatoryFlag': 'option_mealBreakfastIncluded_freeCancellation_payOnArrival',
#         'offerType': 'dbook',
#         'unconfirmedErrorMessage': "If you don't receive an email from Trip.com within an hour, please contact them directly to confirm the exact status of your booking.",
#         'roomId': '14018960',
#         'baseRoomId': '14018960',
#         'bookingData': 'eyJjb3N0Ijp7ImRpc3BsYXlQcmljZSI6eyJwYXJ0bmVyIjoyMjIzLjAxLCJ0cmF2ZWxsZXIiOjIyMjMuMDF9LCJ0b3RhbFdpdGhUYXgiOnsicGFydG5lciI6Mjg4MC42NywidHJhdmVsbGVyIjoyODgwLjY3fX0sInJlcUpxZENsb3NlZFVzZXJHcm91cCI6W10sIm11bHRpUGVyc29uQWR1bHRzIjowfQ==',
#         'benefits': None,
#         'priceIncludes': None,
#         'bedsString': 'Bed type confirmed at check-in',
#         'extraBed': None,
#         'creditCardText': None,
#         'paymentCode': 'uaBlcUut37fCmhplSoIPVYAb+B9R8C64AVHllSW9SGMX+lKKHbAhxUGrKKekmWLvvyvkkmAlj7jtTr5prOhwLA==',
#         'trackingId': '100020771-20240408150645-942d153175444ea9894fdde06a1b39c0',
#         'score': 17}],
#       'cheapestPrice': 2223,
#       'commendatoryValues': ['Breakfast included',
#        'Free cancellation',
#        'Pay on arrival'],
#       'commendatoryFlag': 'option_mealBreakfastIncluded_freeCancellation_payOnArrival'},
#      {'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'}],
#       'rates': [{'acceptedCards': [{'code': 'visa', 'name': 'Visa'},
#          {'code': 'master-card', 'name': 'Mastercard'},
#          {'code': 'american-express', 'name': 'American Express'},
#          {'code': 'jcb', 'name': 'JCB'},
#          {'code': 'unionpay', 'name': 'UnionPay'},
#          {'code': 'diners-club', 'name': 'Diners Club'},
#          {'code': 'discover', 'name': 'Discover'}],
#         'cancellationPolicy': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night.",
#         'cancellationPolicyShortDescription': 'Free cancellation before 4:00 PM on Apr 11, 2024',
#         'freeMessageForRefundable': None,
#         'href': {'adults': 2,
#          'partnerRef': 'd_ct',
#          'paymentType': 'Prepaid',
#          'rateRef': '1703526_1516522680_0_2_1516522680_0_PP',
#          'rooms': 1,
#          'roomRef': '14018960',
#          'partnerPrice': 2880.67,
#          'checkin': '2024-04-13',
#          'version': 2,
#          'instantConfirmation': True,
#          'checkout': '2024-04-20',
#          'partnerCurrency': 'USD'},
#         'hrefHash': 'd383742926c5a358ce93561d4cfacb9cc4e1621fded331c78309181ca34b13831090ee502edebdf9d974aa3e2505797e078cfe81b2aa2ba555adf79532c2b1a4',
#         'rateName': 'Option 5',
#         'price': {'rawTotal': 2223,
#          'total': '$2,223',
#          'totalWithTaxes': '$2,880.67',
#          'rawTotalWithTaxes': 2880.67,
#          'baseTotal': '$2,223.01',
#          'rawBaseTotal': 2223.01,
#          'perNight': '$318',
#          'perNightBreakdown': '($317.57 per night)',
#          'surcharges': {'title': 'Taxes & Fees',
#           'rawTotalTaxes': 657.66,
#           'totalTaxes': '$657.66',
#           'content': [{'name': 'Other', 'amount': '$327.89'},
#            {'name': 'City Tax', 'amount': '$24.50'},
#            {'name': 'Resort Fee', 'amount': '$305.27'}]},
#          'daily': None,
#          'paymentScheduleBreakdown': {'payNow': {'text': '$2,880.67',
#            'info': None,
#            'baselineDelta': 'neutral',
#            'color': 'rgb(17,18,54)'},
#           'payOnArrival': None,
#           'totalWithTaxes': '$2,880.67'}},
#         'rateFeatures': [{'title': 'Instant confirmation',
#           'baselineDelta': 'positive',
#           'key': 'confirmationType',
#           'value': '0',
#           'icon': 'time',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Your booking will be confirmed immediately by {Partner}. You'll immediately receive a confirmation email."}]},
#          {'title': 'Confirmed at check-in',
#           'baselineDelta': 'warning',
#           'key': 'bedType',
#           'value': '1_RUNOFHOUSE',
#           'icon': 'hotels',
#           'color': 'rgb(255,148,0)'},
#          {'title': 'Up to 2 guests',
#           'baselineDelta': 'neutral',
#           'key': 'maxOccupancy',
#           'value': '2',
#           'icon': 'adult',
#           'color': 'rgb(17,18,54)'},
#          {'title': '2x breakfast',
#           'baselineDelta': 'positive',
#           'key': 'mealPlan',
#           'value': 'breakfast_included',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': 'Meals not included',
#             'date': '2024-04-13'},
#            {'text': '2x breakfast', 'date': '2024-04-14'},
#            {'text': '2x breakfast', 'date': '2024-04-15'},
#            {'text': '2x breakfast', 'date': '2024-04-16'},
#            {'text': '2x breakfast', 'date': '2024-04-17'},
#            {'text': '2x breakfast', 'date': '2024-04-18'},
#            {'text': '2x breakfast', 'date': '2024-04-19'},
#            {'text': '2x breakfast', 'date': '2024-04-20'}]},
#          {'title': 'Pay now',
#           'baselineDelta': 'neutral',
#           'key': 'paymentPolicy',
#           'value': 'Prepaid',
#           'icon': 'paid',
#           'color': 'rgb(17,18,54)'},
#          {'title': 'Free cancellation',
#           'baselineDelta': 'positive',
#           'key': 'cancellationPolicy',
#           'value': 'refundable',
#           'icon': 'tick',
#           'color': 'rgb(0,166,152)',
#           'descriptions': [{'text': "Free cancellation before 4:00 PM on Apr 11, 2024 (local time of hotel). After that, you'll be charged for the first night."}]},
#          {'title': 'Non-smoking',
#           'baselineDelta': 'neutral',
#           'key': 'smoking',
#           'value': 'NonSmoking',
#           'icon': 'long-arrow-right',
#           'color': 'rgb(17,18,54)'}],
#         'stickySummary': 'Run Of House - Room Selected At Check In, Option 5, 2x breakfast, Refundable',
#         'partner': {'name': 'Trip.com',
#          'partnerId': 'd_ct',
#          'logo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#          'isOfficial': False},
#         'roomName': 'Run Of House - Room Selected At Check In',
#         'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#           'partnerName': 'Trip.com',
#           'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#           'partnerId': 'd_ct',
#           'fromPartner': 'From Trip.com'}],
#         'cugDeal': None,
#         'couponDeal': None,
#         'commendatoryFlag': 'option_mealBreakfastIncluded_freeCancellation',
#         'offerType': 'dbook',
#         'unconfirmedErrorMessage': "If you don't receive an email from Trip.com within an hour, please contact them directly to confirm the exact status of your booking.",
#         'roomId': '14018960',
#         'baseRoomId': '14018960',
#         'bookingData': 'eyJjb3N0Ijp7ImRpc3BsYXlQcmljZSI6eyJwYXJ0bmVyIjoyMjIzLjAxLCJ0cmF2ZWxsZXIiOjIyMjMuMDF9LCJ0b3RhbFdpdGhUYXgiOnsicGFydG5lciI6Mjg4MC42NywidHJhdmVsbGVyIjoyODgwLjY3fX0sInJlcUpxZENsb3NlZFVzZXJHcm91cCI6W10sIm11bHRpUGVyc29uQWR1bHRzIjowfQ==',
#         'benefits': None,
#         'priceIncludes': None,
#         'bedsString': 'Bed type confirmed at check-in',
#         'extraBed': None,
#         'creditCardText': None,
#         'paymentCode': 'uaBlcUut37fCmhplSoIPVQN7C8OMHDZIVITaH+kb70m+9SnciW20f8y7+NCU8zZ8Fj4Q9FRMTXVufWQ1qUj3bQ==',
#         'trackingId': '100020771-20240408150645-942d153175444ea9894fdde06a1b39c0',
#         'score': 16}],
#       'cheapestPrice': 2223,
#       'commendatoryValues': ['Breakfast included', 'Free cancellation'],
#       'commendatoryFlag': 'option_mealBreakfastIncluded_freeCancellation'}],
#     'rateGroupsCheapestPrice': 1593},
#    {'name': 'Standard King Room',
#     'sizeString': '26 m²',
#     'amenities': [{'key': 'WifiService', 'icon': 'wifi', 'value': 'WiFi'},
#      {'key': 'Shower', 'icon': 'onsen', 'value': 'Shower'},
#      {'key': 'AirConditioning', 'icon': 'aircon', 'value': 'Air conditioning'},
#      {'key': 'Closet', 'icon': 'cloakroom', 'value': 'Wardrobe/Closet'},
#      {'key': 'Desk', 'icon': 'paperclip', 'value': 'Desk'},
#      {'key': 'Heating', 'value': 'Heat'},
#      {'key': 'HotWater24Hours',
#       'icon': 'beer',
#       'value': 'Hot water (24 hours)'},
#      {'key': 'SafeDepositBox', 'icon': 'lock', 'value': 'Safe deposit box'},
#      {'key': 'Television', 'icon': 'media', 'value': 'Television'},
#      {'key': 'CableChannels', 'icon': 'media', 'value': 'Cable TV'},
#      {'key': 'InternationalDirectDial',
#       'icon': 'phone-call',
#       'value': 'International calls available'},
#      {'key': 'Telephone', 'icon': 'phone-call', 'value': 'Telephone'},
#      {'key': 'HairDryer', 'value': 'Hairdryer'},
#      {'key': 'IroningService', 'value': 'Iron'},
#      {'key': 'ShadeCurtain', 'value': 'Shade curtains'}],
#     'size': {'unit': 'm2', 'max': 26, 'min': 26},
#     'baseRoomBedsString': ['1x king bed '],
#     'id': '264729918',
#     'photos': [{'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '264729918',
#       'url': 'https://content.skyscnr.com/moat/images/4fc8c1422d90def7abfa568338be6a9a/4fc8c1422d90def7abfa568338be6a9a_WxH.jpg',
#       'fromPartner': 'From Trip.com'},
#      {'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '264729918',
#       'url': 'https://content.skyscnr.com/moat/images/82854e9bb1ce179e5b6f719d1369fa22/82854e9bb1ce179e5b6f719d1369fa22_WxH.jpg',
#       'fromPartner': 'From Trip.com'},
#      {'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '264729918',
#       'url': 'https://content.skyscnr.com/moat/images/e089da6df3f063dc175b3b4ca7221099/e089da6df3f063dc175b3b4ca7221099_WxH.jpg',
#       'fromPartner': 'From Trip.com'},
#      {'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '264729918',
#       'url': 'https://content.skyscnr.com/moat/images/a4de4fb4fc0de16a412304da739b1af3/a4de4fb4fc0de16a412304da739b1af3_WxH.jpg',
#       'fromPartner': 'From Trip.com'},
#      {'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '264729918',
#       'url': 'https://content.skyscnr.com/moat/images/3583e90993d1d7e17b64285fcfbb27a6/3583e90993d1d7e17b64285fcfbb27a6_WxH.jpg',
#       'fromPartner': 'From Trip.com'},
#      {'partner': 'd_ct',
#       'partner_name': None,
#       'room_id': '264729918',
#       'url': 'https://content.skyscnr.com/moat/images/ec11b846bb31ef25221aee43bad2c265/ec11b846bb31ef25221aee43bad2c265_WxH.jpg',
#       'fromPartner': 'From Trip.com'}],
#     'floors': 'Floors 1-22',
#     'rateGroups': [{'photos': [{'url': 'https://content.skyscnr.com/moat/images/4fc8c1422d90def7abfa568338be6a9a/4fc8c1422d90def7abfa568338be6a9a_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'},
#        {'url': 'https://content.skyscnr.com/moat/images/82854e9bb1ce179e5b6f719d1369fa22/82854e9bb1ce179e5b6f719d1369fa22_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'},
#        {'url': 'https://content.skyscnr.com/moat/images/e089da6df3f063dc175b3b4ca7221099/e089da6df3f063dc175b3b4ca7221099_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'},
#        {'url': 'https://content.skyscnr.com/moat/images/a4de4fb4fc0de16a412304da739b1af3/a4de4fb4fc0de16a412304da739b1af3_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'},
#        {'url': 'https://content.skyscnr.com/moat/images/3583e90993d1d7e17b64285fcfbb27a6/3583e90993d1d7e17b64285fcfbb27a6_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'},
#        {'url': 'https://content.skyscnr.com/moat/images/ec11b846bb31ef25221aee43bad2c265/ec11b846bb31ef25221aee43bad2c265_WxH.jpg',
#         'partnerName': 'Trip.com',
#         'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#         'partnerId': 'd_ct',
#         'fromPartner': 'From Trip.com'}],
#       'rates': [{'acceptedCards': [{'code': 'visa', 'name': 'Visa'},
#          {'code': 'master-card', 'name': 'Mastercard'},
#          {'code': 'american-express', 'name': 'American Express'},
#          {'code': 'jcb', 'name': 'JCB'},
#          {'code': 'unionpay', 'name': 'UnionPay'},
#          {'code': 'diners-club', 'name': 'Diners Club'},
#          {'code': 'discover', 'name': 'Discover'}],
#         'cancellationPolicy': "If you cancel, you'll be charged for 1 night of your stay.",
#         'cancellationPolicyShortDescription': "If you cancel, you'll be charged for 1 night of your stay",
#         'freeMessageForRefundable': None,
#         'href': {'adults': 2,
#          'partnerRef': 'd_ct',
#          'paymentType': 'Prepaid',
# ...
#           'isOfficial': False},
#          'roomName': 'Run Of House - Room Selected At Check In',
#          'photos': [{'url': 'https://content.skyscnr.com/moat/images/eba0b522df4d0dcb6f7eb18e9793b33f/eba0b522df4d0dcb6f7eb18e9793b33f_WxH.jpg',
#            'partnerName': 'Trip.com',
#            'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#            'partnerId': 'd_ct',
#            'fromPartner': 'From Trip.com'}],
#          'cugDeal': None,
#          'couponDeal': None,
#          'commendatoryFlag': 'option_mealBreakfastIncluded_freeCancellation',
#          'offerType': 'dbook',
#          'unconfirmedErrorMessage': "If you don't receive an email from Trip.com within an hour, please contact them directly to confirm the exact status of your booking.",
#          'roomId': '14018960',
#          'baseRoomId': '14018960',
#          'bookingData': 'eyJjb3N0Ijp7ImRpc3BsYXlQcmljZSI6eyJwYXJ0bmVyIjoyMjIzLjAxLCJ0cmF2ZWxsZXIiOjIyMjMuMDF9LCJ0b3RhbFdpdGhUYXgiOnsicGFydG5lciI6Mjg4MC42NywidHJhdmVsbGVyIjoyODgwLjY3fX0sInJlcUpxZENsb3NlZFVzZXJHcm91cCI6W10sIm11bHRpUGVyc29uQWR1bHRzIjowfQ==',
#          'benefits': None,
#          'priceIncludes': None,
#          'bedsString': 'Bed type confirmed at check-in',
#          'extraBed': None,
#          'creditCardText': None,
#          'paymentCode': 'uaBlcUut37fCmhplSoIPVQN7C8OMHDZIVITaH+kb70m+9SnciW20f8y7+NCU8zZ8Fj4Q9FRMTXVufWQ1qUj3bQ==',
#          'trackingId': '100020771-20240408150645-942d153175444ea9894fdde06a1b39c0',
#          'score': 16}],
#        'cheapestPrice': 2223,
#        'commendatoryValues': ['Breakfast included', 'Free cancellation'],
#        'commendatoryFlag': 'option_mealBreakfastIncluded_freeCancellation'}],
#      'rateGroupsCheapestPrice': 1593},
#     'rawPrice': 228,
#     'price': '$228',
#     'score': 32},
#    {'partnerName': 'Hotels.com',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_hc.png',
#     'partnerId': 'h_hc',
#     'roomType': 'Room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_hc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=17&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 30,
#     'funnelType': 'meta'},
#    {'partnerName': 'Booking.com',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_bc.png',
#     'partnerId': 'h_bc',
#     'roomType': 'Double room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_bc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=13&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included',
#      'Non-Refundable',
#      'Double room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 25,
#     'funnelType': 'meta'}],
#   'noOfferPartners': [{'is_official': False,
#     'is_dbook': False,
#     'name': 'Getaroom',
#     'website_id': 'h_gt',
#     'logo': 'www.skyscanner.com/images/websites/220x80/h_gt.png',
#     'partner_type': 'OTA'},
#    {'is_official': False,
#     'is_dbook': False,
#     'name': 'Algotels',
#     'website_id': 'h_tt',
#     'logo': 'www.skyscanner.com/images/websites/220x80/h_tt.png',
#     'partner_type': 'OTA'},
#    {'is_official': True,
#     'is_dbook': False,
#     'name': 'WIHP Hotels',
#     'website_id': 'h_wp',
#     'logo': 'www.skyscanner.com/images/websites/220x80/h_wp.png',
#     'partner_type': 'Chain'},
#    {'is_official': False,
#     'is_dbook': False,
#     'name': 'Agoda',
#     'website_id': 'h_ad',
#     'logo': 'www.skyscanner.com/images/websites/220x80/h_ad.png',
#     'partner_type': 'OTA'}],
#   'isShowMostPopularSeeAll': True,
#   'policyInfo': 'Taxes and fees not included.',
#   'otaRates': [{'partnerName': 'SuperTravel',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_11.png',
#     'partnerId': 'h_11',
#     'roomType': 'Double room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_11/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=926482&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1235.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJiOWU3ZmQwNjRjMTA5YzUwZDQ5OWZlOTMyOWQ4OTk5ZSJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnN1cGVyLmNvbS90cmF2ZWwvdHJhbnNpdGlvbi8%...&max_price=2543.0&channel=iphone',
#     'rawPrice': 176,
#     'rawPriceGbp': 140,
#     'price': '$176',
#     'rateBriefFeatures': ['Meals not included',
#      'Non-Refundable',
#      'Double room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 34,
#     'funnelType': 'meta'},
#    {'partnerName': 'Prestigia',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_pi.png',
#     'partnerId': 'h_pi',
#     'roomType': 'Double room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pi/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=75&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1426.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICIyNjVkMDZkOGJmMmY4NjY3MmNiOTA4NzNhNGJkMmRjMiJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnByZXN0aWdpYS5jb20vZW4vcHJvZHVpdC5waHA%...%3D%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 204,
#     'rawPriceGbp': 161,
#     'price': '$204',
#     'rateBriefFeatures': ['Meals not included',
#      'Non-Refundable',
#      'Double room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 33,
#     'funnelType': 'meta'},
#    {'partnerName': 'Expedia',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_xp.png',
#     'partnerId': 'h_xp',
#     'roomType': 'Room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_xp/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=1&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 31,
#     'funnelType': 'meta'},
#    {'partnerName': 'Hotels.com',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_hc.png',
#     'partnerId': 'h_hc',
#     'roomType': 'Room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_hc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=17&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 30,
#     'funnelType': 'meta'},
#    {'partnerName': 'Travelocity',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_tc.png',
#     'partnerId': 'h_tc',
#     'roomType': 'Room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_tc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927567&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJkODViNzFjYThiYmQ5MmRjNTBiZmRhZWIwMzU5NGRjNyJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnRyYXZlbG9jaXR5LmNvbS9Ib3RlbC1TZWFyY2g%%3D%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 29,
#     'funnelType': 'meta'},
#    {'partnerName': 'ZenHotels',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_zh.png',
#     'partnerId': 'h_zh',
#     'roomType': 'Room',
#     'roomPolicies': 'Room Only, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_zh/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927794&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Room Only', 'Non-Refundable', 'Room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 28,
#     'funnelType': 'meta'},
#    {'partnerName': 'Priceline',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_pr.png',
#     'partnerId': 'h_pr',
#     'roomType': 'Room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pr/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=151&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 27,
#     'funnelType': 'meta'},
#    {'partnerName': 'Edreams',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_ei.png',
#     'partnerId': 'h_ei',
#     'roomType': 'Double room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_ei/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927018&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included',
#      'Non-Refundable',
#      'Double room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 26,
#     'funnelType': 'meta'},
#    {'partnerName': 'Booking.com',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_bc.png',
#     'partnerId': 'h_bc',
#     'roomType': 'Double room',
#     'roomPolicies': 'Meals not included, Non-Refundable',
#     'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_bc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=13&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone',
#     'rawPrice': 228,
#     'rawPriceGbp': 180,
#     'price': '$228',
#     'rateBriefFeatures': ['Meals not included',
#      'Non-Refundable',
#      'Double room'],
#     'isOfficial': False,
#     'isShowHotelName': False,
#     'score': 25,
#     'funnelType': 'meta'},
#    {'partnerName': 'Trip.com',
#     'partnerId': 'd_ct',
#     'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/d_ct.png',
#     'price': '$228',
#     'perNight': '$228',
#     'rawPrice': 228,
#     'roomType': 'Run Of House - Room Selected At Check In',
#     'href': {'adults': 2,
#      'partnerRef': 'd_ct',
#      'paymentType': 'Prepaid',
#      'rateRef': '1703526_1516523597_0_2_1516523597_0_PP',
#      'rooms': 1,
#      'roomRef': '14018960',
#      'partnerPrice': 2157.94,
#      'checkin': '2024-04-13',
#      'version': 2,
#      'instantConfirmation': True,
#      'checkout': '2024-04-20',
#      'partnerCurrency': 'USD'},
#     'funnelType': 'dbook',
#     'score': 32}],
#   'roomFilters': [{'filterName': 'Bed type',
#     'bedTypes': [{'title': 'Confirmed at check-in', 'value': '1_RUNOFHOUSE'},
#      {'title': '1 x king bed', 'value': '1_KING'},
#      {'title': '2 x double bed ', 'value': '2_DOUBLE'}],
#     'key': 'bedType',
#     'selected': False,
#     'type': 'MULTIPLE_SELECTION'},
#    {'filterName': 'Free cancellation',
#     'key': 'cancellationPolicy',
#     'selected': False,
#     'type': 'DIRECT_SELECTION'},
#    {'filterName': 'Some meals included',
#     'key': 'mealPlan',
#     'selected': False,
#     'type': 'DIRECT_SELECTION'},
#    {'filterName': 'Pay on arrival',
#     'key': 'paymentPolicy',
#     'selected': False,
#     'type': 'DIRECT_SELECTION'},
#    {'filterName': 'Instant confirmation',
#     'key': 'confirmationType',
#     'selected': False,
#     'type': 'DIRECT_SELECTION'}],
#   'localCurrency': 'USD',
#   'searchId': 'ea72e9674f533686b584a5998ef619e0f48c77118649e098f2574ca0bcc80a88',
#   'requestId': '642c5800-d5bc-464d-8834-ba4ba5f8514e'}}

# %% [markdown]
# JSON object will be converted into a `dict` type, which is the data structure in Python holding key value pairs. To access certain values, we just access them like a `dict`.

# %%
hotel_labels = hotel['data']['metaInfo']['rates']
print(hotel_labels)
# Out:
# [{'partnerName': 'SuperTravel', 'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_11.png', 'partnerId': 'h_11', 'roomType': 'Double room', 'roomPolicies': 'Meals not included, Non-Refundable', 'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_11/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=926482&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1235.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJiOWU3ZmQwNjRjMTA5YzUwZDQ5OWZlOTMyOWQ4OTk5ZSJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnN1cGVyLmNvbS90cmF2ZWwvdHJhbnNpdGlvbi8%...&max_price=2543.0&channel=iphone', 'rawPrice': 176, 'rawPriceGbp': 140, 'price': '$176', 'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Double room'], 'isOfficial': False, 'isShowHotelName': False, 'score': 34}, {'partnerName': 'Prestigia', 'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_pi.png', 'partnerId': 'h_pi', 'roomType': 'Double room', 'roomPolicies': 'Meals not included, Non-Refundable', 'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pi/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=75&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1426.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICIyNjVkMDZkOGJmMmY4NjY3MmNiOTA4NzNhNGJkMmRjMiJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnByZXN0aWdpYS5jb20vZW4vcHJvZHVpdC5waHA%...%3D%3D&max_price=2543.0&channel=iphone', 'rawPrice': 204, 'rawPriceGbp': 161, 'price': '$204', 'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Double room'], 'isOfficial': False, 'isShowHotelName': False, 'score': 33}, {'partnerName': 'Expedia', 'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_xp.png', 'partnerId': 'h_xp', 'roomType': 'Room', 'roomPolicies': 'Meals not included, Non-Refundable', 'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_xp/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=1&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone', 'rawPrice': 228, 'rawPriceGbp': 180, 'price': '$228', 'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'], 'isOfficial': False, 'isShowHotelName': False, 'score': 31}, {'partnerName': 'Hotels.com', 'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_hc.png', 'partnerId': 'h_hc', 'roomType': 'Room', 'roomPolicies': 'Meals not included, Non-Refundable', 'deeplink': 'www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_hc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=17&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...&max_price=2543.0&channel=iphone', 'rawPrice': 228, 'rawPriceGbp': 180, 'price': '$228', 'rateBriefFeatures': ['Meals not included', 'Non-Refundable', 'Room'], 'isOfficial': False, 'isShowHotelName': False, 'score': 30}, {'partnerName': 'Travelocity', 'partnerLogo': 'https://www.skyscanner.com/images/websites/220x80/h_tc.png', 'partnerId': 'h_tc', 'roomType': 'Room', 'roomPolicies': 'Meals not included, Non-Refundable', 'deeplink': 'www.skyscanner.com/hot ...

# %%
for labels in hotel_labels:
    for key, value in labels.items():
        print(key, value)
# Out:
# partnerName SuperTravel
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_11.png
# partnerId h_11
# roomType Double room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_11/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=926482&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1235.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJiOWU3ZmQwNjRjMTA5YzUwZDQ5OWZlOTMyOWQ4OTk5ZSJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnN1cGVyLmNvbS90cmF2ZWwvdHJhbnNpdGlvbi8%...&max_price=2543.0&channel=iphone
# rawPrice 176
# rawPriceGbp 140
# price $176
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Double room']
# isOfficial False
# isShowHotelName False
# score 34
# partnerName Prestigia
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_pi.png
# partnerId h_pi
# roomType Double room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pi/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=75&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1426.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICIyNjVkMDZkOGJmMmY4NjY3MmNiOTA4NzNhNGJkMmRjMiJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnByZXN0aWdpYS5jb20vZW4vcHJvZHVpdC5waHA%...%3D%3D&max_price=2543.0&channel=iphone
# rawPrice 204
# rawPriceGbp 161
# price $204
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Double room']
# isOfficial False
# isShowHotelName False
# score 33
# partnerName Expedia
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_xp.png
# partnerId h_xp
# roomType Room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_xp/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=1&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Room']
# isOfficial False
# isShowHotelName False
# score 31
# partnerName Hotels.com
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_hc.png
# partnerId h_hc
# roomType Room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_hc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=17&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Room']
# isOfficial False
# isShowHotelName False
# score 30
# partnerName Travelocity
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_tc.png
# partnerId h_tc
# roomType Room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_tc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927567&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICJkODViNzFjYThiYmQ5MmRjNTBiZmRhZWIwMzU5NGRjNyJ9LCAidXJsIjogImh0dHBzOi8vd3d3LnRyYXZlbG9jaXR5LmNvbS9Ib3RlbC1TZWFyY2g%%3D%3D&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Room']
# isOfficial False
# isShowHotelName False
# score 29
# partnerName ZenHotels
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_zh.png
# partnerId h_zh
# roomType Room
# roomPolicies Room Only, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_zh/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927794&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D%3D&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Room Only', 'Non-Refundable', 'Room']
# isOfficial False
# isShowHotelName False
# score 28
# partnerName Priceline
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_pr.png
# partnerId h_pr
# roomType Room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_pr/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=151&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=...%3D&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Room']
# isOfficial False
# isShowHotelName False
# score 27
# partnerName Edreams
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_ei.png
# partnerId h_ei
# roomType Double room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_ei/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=927018&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Double room']
# isOfficial False
# isShowHotelName False
# score 26
# partnerName Booking.com
# partnerLogo https://www.skyscanner.com/images/websites/220x80/h_bc.png
# partnerId h_bc
# roomType Double room
# roomPolicies Meals not included, Non-Refundable
# deeplink www.skyscanner.com/hotel_deeplink/4.0/US/en-US/USD/h_bc/106005202/2024-04-13/2024-04-20/hotel/hotel/hotels?guests=2&rooms=1&legacy_provider_id=13&request_id=642c5800-d5bc-464d-8834-ba4ba5f8514e&q_datetime_utc=2024-04-08T07%3A06%3A50&redirect_delay=1000&appName=goiPhone&appVersion=7.92.1&client_id=skyscanner_app&tm_city_code=NYCA&tm_country_code=US&tm_place_name=New+York&tm_stars=4&ticket_price=1593.0&deeplink_data=eyJmaWVsZHMiOiB7InNpZ25hdHVyZSI6ICI5YjUwY2Y1MjdkMDM0MDdhYWQxYjlmNjQzZWZlMTZhYiIsICJibG9ja19pZCI6ICI0MzY4MjcxN185NzQ5MDMzOV8yXzJfMCJ9fQ%3D%3D&max_price=2543.0&channel=iphone
# rawPrice 228
# rawPriceGbp 180
# price $228
# rateBriefFeatures ['Meals not included', 'Non-Refundable', 'Double room']
# isOfficial False
# isShowHotelName False
# score 25

# %% [markdown]
# Now it gets interesting, as we can put the values into a dataframe (more on dataframes later).

# %%
import pandas as pd

lst = []

for values in hotel_labels:
    lst.append(pd.DataFrame.from_dict(values, orient='index').transpose())

# %%
df = pd.concat(lst).reset_index()

# %%
df
# Out:
#    index  partnerName                                        partnerLogo  \
# 0      0  SuperTravel  https://www.skyscanner.com/images/websites/220...
# 1      0    Prestigia  https://www.skyscanner.com/images/websites/220...
# 2      0      Expedia  https://www.skyscanner.com/images/websites/220...
# 3      0   Hotels.com  https://www.skyscanner.com/images/websites/220...
# 4      0  Travelocity  https://www.skyscanner.com/images/websites/220...
# 5      0    ZenHotels  https://www.skyscanner.com/images/websites/220...
# 6      0    Priceline  https://www.skyscanner.com/images/websites/220...
# 7      0      Edreams  https://www.skyscanner.com/images/websites/220...
# 8      0  Booking.com  https://www.skyscanner.com/images/websites/220...
#
#   partnerId     roomType                        roomPolicies  \
# 0      h_11  Double room  Meals not included, Non-Refundable
# 1      h_pi  Double room  Meals not included, Non-Refundable
# 2      h_xp         Room  Meals not included, Non-Refundable
# 3      h_hc         Room  Meals not included, Non-Refundable
# 4      h_tc         Room  Meals not included, Non-Refundable
# 5      h_zh         Room           Room Only, Non-Refundable
# 6      h_pr         Room  Meals not included, Non-Refundable
# 7      h_ei  Double room  Meals not included, Non-Refundable
# 8      h_bc  Double room  Meals not included, Non-Refundable
#
#                                             deeplink rawPrice rawPriceGbp  \
# 0  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      176         140
# 1  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      204         161
# 2  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
# 3  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
# 4  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
# 5  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
# 6  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
# 7  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
# 8  www.skyscanner.com/hotel_deeplink/4.0/US/en-US...      228         180
#
#   price                                  rateBriefFeatures isOfficial  \
# 0  $176  [Meals not included, Non-Refundable, Double room]      False
# 1  $204  [Meals not included, Non-Refundable, Double room]      False
# 2  $228         [Meals not included, Non-Refundable, Room]      False
# 3  $228         [Meals not included, Non-Refundable, Room]      False
# 4  $228         [Meals not included, Non-Refundable, Room]      False
# 5  $228                  [Room Only, Non-Refundable, Room]      False
# 6  $228         [Meals not included, Non-Refundable, Room]      False
# 7  $228  [Meals not included, Non-Refundable, Double room]      False
# 8  $228  [Meals not included, Non-Refundable, Double room]      False
#
#   isShowHotelName score
# 0           False    34
# 1           False    33
# 2           False    31
# 3           False    30
# 4           False    29
# 5           False    28
# 6           False    27
# 7           False    26
# 8           False    25

# %% [markdown]
# ### Use packages: Twitter API as an example

# %% [markdown]
# Many web servers have their own APIs ready to use. By using these convenient tools, we can get started right off following their documentations and examples without any manual efforts.
#
# We will be using <a href="https://apps.twitter.com/" target="_blank">Twitter API</a> as an example. We will first install this package as shown [here](https://python-twitter.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# You have to register an account for Twitter Developer and register an app.
#
# - go to https://dev.twitter.com/ and get an app togther. <a href="https://python-twitter.readthedocs.io/en/latest/getting_started.html" target="_b lank">Here</a>'s a quick start on how you can do this.
#
# After obtaining *__consumer key__*, *__consumer secret__*, *__access token__*, and *__access token secret__*, you are ready to retrieve some data from Twitter!

# %% [markdown]
# I have created a .env file in my root folder in the following way:
#
# ```
# consumer_key = your_consumer_key
# consumer_secret = your_consumer_secret
# access_token = your_access_token
# access_secret = your_access_secret
# ```

# %%
# Read the keys and tokens into a dictionary
my_dict = {}

with open("../.env", "r") as f:
    for line in f:
        key,val = line.split('=')
        my_dict[key.strip()] = val.strip()

# %%
my_dict
# Out:
# {'api_key': '98ec120f-22ae-4c65-bee5-c7979ce58fe2',
#  'consumer_key': 'pxckjDmamJ3MFSB4zbfGsf81X',
#  'consumer_secret': 'C0c16vwne2UjhcNCW7gv0h2NfqpTDOG4IkYFc8ccpvTyjg6fRv',
#  'access_token': '966273572015624192-VUvEJelTQGTYQijFRJhvbPqz6IqVlLK',
#  'access_secret': 'GCjsYL7lfj54tedcnznjQMJmJv6WNo86t20h4QPK29f37'}

# %%
## load twitter package, which a well-written Python package for Twitter APIs
import twitter
api = twitter.Api(consumer_key=my_dict['consumer_key'],
                  consumer_secret=my_dict['consumer_secret'],                  
                  access_token_key=my_dict['access_token'],
                  access_token_secret=my_dict['access_secret'])

## check status
api.VerifyCredentials()
# Out:
# User(ID=966273572015624192, ScreenName=PetriBagger)

# %%
statuses = api.GetUserTimeline(screen_name="PetriBagger")
for s in statuses:
    print(s.text)
# Out:
# @BornsVilkar @trygfonden @sanne_lind @politiken Det er en temmelig frisk konklusion at smide ud i offentligheden ud… https://t.co/HlVxJuvuWg
# #kapacity testing Azure logic apps
# RT @JosephineFock: Stop den overvågning, helt uacceptabelt at vi fortsat overvåger os alle #dkpol #stoplogning https://t.co/aIFu18Y8hj
# Jeg håber flere vil ty til civil ulydighed og boykotte de nationale trivselsmålinger af vores børn. Det er forrykt… https://t.co/GAf4zIJIvF

# %%
statuses = api.GetUserTimeline(user_id="966273572015624192")
for s in statuses:
    print(s.created_at)
# Out:
# Tue May 05 18:12:25 +0000 2020
# Thu Oct 25 07:24:33 +0000 2018
# Sun Mar 18 20:51:56 +0000 2018
# Mon Mar 12 21:52:22 +0000 2018

# %%
friends = api.GetFriends()
for f in friends:
    print(f.name)
# Out:
# Jakob Sorgenfri Kjær
# SpeakerAllan
# AllanGravgaardMadsen
# Jeppe Søe
# Erik Lahm
# Nielbo
# Astrid Porsmose
# Thor Hampus Bank
# Kirsten Birgit
# Søren Bo Steendahl
# Carl Johannes Borris
# Morten H.J. Fenger
# Martin Ibsen

# %% [markdown]
# More interestingly, let's go get some tweets from Twitter. Let's try to search for tweets related to `gpt4` since 01/01/2023 in English.
# - See https://dev.twitter.com/rest/public/search for more informaiton on how to construct a query

# %%
results = api.GetSearch(
    raw_query="q=gpt4&src=typed_query&since=2023-01-01&lang=en")

# %%
len(results)
# Out:
# 15

# %%
print(results)
# Out:
# [Status(ID=1638131840908419074, ScreenName=JLLEWIS0000, Created=Tue Mar 21 10:54:00 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/Trw8nmEidZ\n\n  #airdrop #NFT $HEX $SUI… https://t.co/vwZ4krb2nR'), Status(ID=1638131839263993856, ScreenName=TrackierHQ, Created=Tue Mar 21 10:54:00 +0000 2023, Text="We tried creating ad copies for our Mobile Marketing Platform using @HubSpot's latest https://t.co/n2SMtwH2xQ. \n\nHe… https://t.co/tqJXvbthwT"), Status(ID=1638131830204542977, ScreenName=MehdiBahramii, Created=Tue Mar 21 10:53:57 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/tXrxXEYZ2C\n\n  #airdrop #NFT $ETH $GPT4… https://t.co/BjwonlFy69'), Status(ID=1638131814060683264, ScreenName=Breezy_Shawtey, Created=Tue Mar 21 10:53:54 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/3C0qXRsRX1\n\n  #airdrop #NFT $BNB $RDNT… https://t.co/WhJ1F4xdnW'), Status(ID=1638131785715404801, ScreenName=DatzRealDae, Created=Tue Mar 21 10:53:47 +0000 2023, Text='RT @inbox1402: $GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/9lwI4VcpO6\n\n  #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4 $SSV $ARB $…'), Status(ID=1638131783727284231, ScreenName=sbc111, Created=Tue Mar 21 10:53:46 +0000 2023, Text='ChatGPT-assisted diagnosis: Is the future suddenly here? | @statnews  \n#AI #ChatGPT #chatgpt4 #GPT4 #HealthTech… https://t.co/JThhbZF2nw'), Status(ID=1638131763980664833, ScreenName=avocatvo, Created=Tue Mar 21 10:53:42 +0000 2023, Text='Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥 \n\n👉https://t.co/xn0WlXa4yn\n\n  #airdrop #NFT… https://t.co/lstjt1CEos'), Status(ID=1638131706443227136, ScreenName=JovanCokleski, Created=Tue Mar 21 10:53:28 +0000 2023, Text='Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥 \n\n👉https://t.co/7sGNg3JqcT\n\n  #airdrop #NFT… https://t.co/EfRZ9uDgkH'), Status(ID=1638131606652358656, ScreenName=inbox1402, Created=Tue Mar 21 10:53:04 +0000 2023, Text='$GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/9lwI4VcpO6\n\n  #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4… https://t.co/cyxkz7cKfg'), Status(ID=1638131515845648385, ScreenName=jearachelle, Created=Tue Mar 21 10:52:43 +0000 2023, Text="#GPT4 has only been out a week, and it's already changing lives. Ape and use $GPT4 to fuck yourself🚀🚀 \n\n👉… https://t.co/gp0DCYPLzI"), Status(ID=1638131493162696705, ScreenName=camino_ss, Created=Tue Mar 21 10:52:37 +0000 2023, Text='RT @lexus69778802: GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/Edn5cr7wM4\n\n  #airdrop #NFT #crypto $CFX $IM…'), Status(ID=1638131458090094595, ScreenName=SMERKINATOR, Created=Tue Mar 21 10:52:29 +0000 2023, Text='$GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/iXg2FdX0iW\n\n  #airdrop #NFT $RDNT $GPT $FIL $SUI $APT… https://t.co/EMAy01jGjt'), Status(ID=1638131429627551745, ScreenName=RLadyzhensky, Created=Tue Mar 21 10:52:22 +0000 2023, Text='$GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/OSyOWmjdvk\n\n  #airdrop #NFT $SHI $BONK #ChatGPT #AI $GPT4… https://t.co/CImFh5YzBO'), Status(ID=1638131408769015808, ScreenName=blacksheepsteem, Created=Tue Mar 21 10:52:17 +0000 2023, Text='@realKilovoltage @Scrypto_Lang @radixdlt Still early but inevitable i think. Such a great way to learn. With more c… https://t.co/HYIMZ2RBoN'), Status(ID=1638131399726346240, ScreenName=jpfreemon, Created=Tue Mar 21 10:52:15 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/2eqwW1wu3M\n\n  #airdrop #NFT #GPT4 $ETH… https://t.co/kA0cIxn2fH')]

# %%
from IPython.display import clear_output
for tw in results:
    print("%s. Tweeted by \033[41m%s\033[0m"%(tw.text, tw.user.screen_name))
# Out:
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/Trw8nmEidZ
#
#   #airdrop #NFT $HEX $SUI… https://t.co/vwZ4krb2nR. Tweeted by JLLEWIS0000
# We tried creating ad copies for our Mobile Marketing Platform using @HubSpot's latest https://t.co/n2SMtwH2xQ.
#
# He… https://t.co/tqJXvbthwT. Tweeted by TrackierHQ
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/tXrxXEYZ2C
#
#   #airdrop #NFT $ETH $GPT4… https://t.co/BjwonlFy69. Tweeted by MehdiBahramii
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/3C0qXRsRX1
#
#   #airdrop #NFT $BNB $RDNT… https://t.co/WhJ1F4xdnW. Tweeted by Breezy_Shawtey
# RT @inbox1402: $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/9lwI4VcpO6
#
#   #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4 $SSV $ARB $…. Tweeted by DatzRealDae
# ChatGPT-assisted diagnosis: Is the future suddenly here? | @statnews
# #AI #ChatGPT #chatgpt4 #GPT4 #HealthTech… https://t.co/JThhbZF2nw. Tweeted by sbc111
# Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥
#
# 👉https://t.co/xn0WlXa4yn
#
#   #airdrop #NFT… https://t.co/lstjt1CEos. Tweeted by avocatvo
# Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥
#
# 👉https://t.co/7sGNg3JqcT
#
#   #airdrop #NFT… https://t.co/EfRZ9uDgkH. Tweeted by JovanCokleski
# $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/9lwI4VcpO6
#
#   #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4… https://t.co/cyxkz7cKfg. Tweeted by inbox1402
# #GPT4 has only been out a week, and it's already changing lives. Ape and use $GPT4 to fuck yourself🚀🚀
#
# 👉… https://t.co/gp0DCYPLzI. Tweeted by jearachelle
# RT @lexus69778802: GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/Edn5cr7wM4
#
#   #airdrop #NFT #crypto $CFX $IM…. Tweeted by camino_ss
# $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/iXg2FdX0iW
#
#   #airdrop #NFT $RDNT $GPT $FIL $SUI $APT… https://t.co/EMAy01jGjt. Tweeted by SMERKINATOR
# $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/OSyOWmjdvk
#
#   #airdrop #NFT $SHI $BONK #ChatGPT #AI $GPT4… https://t.co/CImFh5YzBO. Tweeted by RLadyzhensky
# @realKilovoltage @Scrypto_Lang @radixdlt Still early but inevitable i think. Such a great way to learn. With more c… https://t.co/HYIMZ2RBoN. Tweeted by blacksheepsteem
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/2eqwW1wu3M
#
#   #airdrop #NFT #GPT4 $ETH… https://t.co/kA0cIxn2fH. Tweeted by jpfreemon

# %% [markdown]
# I went through some examples of using APIs to get various types of data in Python. The last Twitter example is relatively superficial. There are other packages to twitter, [`tweepy`] package seems to be pretty popular as well: http://www.tweepy.org/

# %% [markdown]
# return to [overview](../00_overview.ipynb)
