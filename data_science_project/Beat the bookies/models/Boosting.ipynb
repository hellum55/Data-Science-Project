# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import sklearn.model_selection as skm

# %%
from sklearn.tree import (DecisionTreeClassifier as DTC, DecisionTreeRegressor as DTR, plot_tree , export_text)
from sklearn.ensemble import \
(RandomForestRegressor as RF, GradientBoostingRegressor as GBR)

# %%
from sklearn.metrics import (accuracy_score,log_loss)
from sklearn.ensemble import (RandomForestRegressor as RF,GradientBoostingRegressor as GBR,
                             GradientBoostingClassifier as GBC,
                             BaggingClassifier as BC)

# %%
pred = pd.read_csv("/Users/christianhellum/Cand. Merc./Data-Science-Project/data_science_project/Beat the bookies/data/df_preprocessed.csv", index_col=0)

# %%
pred
# Out:
#             Date  Home  Away FTR  Attendance  B365H  B365D  B365A  \
# 0     2019-08-16     2     4   H     47693.0   5.25   3.80   1.65
# 1     2019-08-17     6    21   A     23566.0   4.75   4.20   1.65
# 2     2019-08-17    24    22   D     41846.0   1.66   3.75   5.50
# 3     2019-08-17    18     8   H     15127.0   2.80   3.20   2.60
# 4     2019-08-17    16    19   A     10020.0   2.00   3.20   4.20
# ...          ...   ...   ...  ..         ...    ...    ...    ...
# 1855  2024-05-05    19     5   A     18300.0   3.20   3.25   2.38
# 1856  2024-05-05     6    26   H     19548.0   2.30   3.60   2.88
# 1857  2024-05-05    24     0   A     44643.0   2.10   3.00   4.00
# 1858  2024-05-05    20     1   A     10864.0   1.57   4.00   5.75
# 1859  2024-05-05    23    13   H     32658.0   1.65   4.00   5.25
#
#       AttackStrengthHome  AttackStrengthAway  ...  AvgHomeShotsOnTargetLast5  \
# 0               0.000000            0.000000  ...                        0.0
# 1               0.000000            0.000000  ...                        0.0
# 2               0.000000            0.000000  ...                        0.0
# 3               0.000000            0.000000  ...                        0.0
# 4               0.000000            0.000000  ...                        0.0
# ...                  ...                 ...  ...                        ...
# 1855            0.034274            0.044503  ...                        3.0
# 1856            0.028226            0.065104  ...                        5.6
# 1857            0.038076            0.028497  ...                        4.4
# 1858            0.032064            0.041344  ...                        4.0
# 1859            0.046092            0.033505  ...                        4.8
#
#       AvgAwayShotsLast5  AvgAwayShotsOnTargetLast5          elo     elo_away  \
# 0                   0.0                        0.0  1722.019409  2001.228638
# 1                   0.0                        0.0  1681.163452  1841.848999
# 2                   0.0                        0.0  1813.655029  1719.431152
# 3                   0.0                        0.0  1566.961060  1712.778198
# 4                   0.0                        0.0  1670.794800  1641.649048
# ...                 ...                        ...          ...          ...
# 1855               11.0                        4.4  1629.822266  1696.406372
# 1856                9.0                        3.4  1628.082397  1724.820923
# 1857                9.8                        3.4  1687.701660  1622.472412
# 1858                8.2                        2.6  1621.235840  1527.045044
# 1859                8.6                        2.6  1696.177856  1563.006226
#
#       FormHomeTeam  FormAwayTeam  ProbabilityDraw  ProbabilityHomeWin  \
# 0         0.000000      0.000000         0.226260            0.127955
# 1         0.000000      0.000000         0.239320            0.266267
# 2         0.000000      0.000000         0.229859            0.616701
# 3         0.000000      0.000000         0.240204            0.286297
# 4         0.000000      0.000000         0.237143            0.533531
# ...            ...           ...              ...                 ...
# 1855   2057.936660   2057.038916         0.241897            0.398349
# 1856   2338.240591   3718.007305         0.241856            0.355002
# 1857   2059.229795   1340.504648         0.233489            0.580879
# 1858   2925.893320   1647.954297         0.229864            0.616662
# 1859   3392.680273    672.267695         0.224066            0.661280
#
#       ProbabilityAwayWin
# 0               0.645785
# 1               0.494412
# 2               0.153439
# 3               0.473499
# 4               0.229326
# ...                  ...
# 1855            0.359754
# 1856            0.403142
# 1857            0.185632
# 1858            0.153475
# 1859            0.114654
#
# [1860 rows x 35 columns]

# %%
pred['Home'] = pred['Home'].astype('category')
pred['Away'] = pred['Away'].astype('category')
pred['FTR'] = pred['FTR'].astype('category')

# %%
model = MS(pred.columns.drop(['FTR', 'Date']), intercept=False)
D = model.fit_transform(pred)
feature_names = list(D.columns)
X = np.asarray(D)

# %%
y=pred['FTR']
(X_train, X_test, y_train, y_test) = skm.train_test_split(X,y,train_size=1700,random_state=1)

# %%
#Boosting
boost_pred = GBC(random_state=0, n_estimators=40, learning_rate=0.01, max_depth=3)
boost_pred.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, n_estimators=40, random_state=0)

# %%
ypred = boost_pred.predict(X_test)
ypred_train = boost_pred.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(classification_report(y_test, ypred))
print(classification_report(y_train, ypred_train))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.40      0.26      0.31        39
#            D       0.00      0.00      0.00        41
#            H       0.53      0.89      0.66        80
#
#     accuracy                           0.51       160
#    macro avg       0.31      0.38      0.32       160
# weighted avg       0.36      0.51      0.41       160
#
#               precision    recall  f1-score   support
#
#            A       0.65      0.41      0.51       481
#            D       1.00      0.01      0.01       468
#            H       0.51      0.94      0.66       751
#
#     accuracy                           0.54      1700
#    macro avg       0.72      0.45      0.39      1700
# weighted avg       0.68      0.54      0.44      1700
# /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
