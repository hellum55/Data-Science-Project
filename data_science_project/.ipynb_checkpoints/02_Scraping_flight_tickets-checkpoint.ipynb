# %% [markdown]
# # Web Crawling and web Scraping

# %% [markdown]
# Save this code to your disk as `sample.html` (or any other name). We will use a great library called ___`Beautiful Soup`___ to read the contents from Python. You may also need to install lxml, which is for parsing specific formats (e.g., html and xml).
#
#     pip install beautifulsoup4 lxml

# %%
pip install lxml pandas selenium bs4 webdriver_manager
# Out:
# Requirement already satisfied: lxml in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (5.2.1)
# Requirement already satisfied: pandas in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: selenium in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (4.19.0)
# Requirement already satisfied: bs4 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (0.0.2)
# Collecting webdriver_manager
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.1)
# Requirement already satisfied: trio~=0.17 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from selenium) (4.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: requests in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from webdriver_manager) (2.31.0)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: packaging in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from webdriver_manager) (24.0)
# Requirement already satisfied: six>=1.5 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from requests->webdriver_manager) (3.3.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/christianhellum/Library/Caches/pypoetry/virtualenvs/data-science-project-PFmYB0_u-py3.12/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.1 webdriver_manager-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
## Do the following if you have not
from time import sleep, strftime
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as Soup

# %%
driver = webdriver.Chrome()
to_location = 'AGP'
from_location = 'BLL'
date_start = '2024-08-03'

url = 'https://www.kayak.dk/flights/{from_location}-{to_location}/{date_start}-flexible-2days/2adults?fs=cfc=1&sort=bestflight_a'.format(to_location=to_location, from_location=from_location, date_start=date_start)

# %%
driver.get(url)
# Attempt to click on the popup window
sleep(10)
driver.find_element("xpath", '//*[@id="portal-container"]/div/div[2]/div/div/div[1]/div/span[2]/button').click()

# %%
driver.find_element(By.CLASS_NAME, 'ULvh').click()

# %%
flight_rows = driver.find_elements(By.XPATH, '//div[@class="nrc6-wrapper"]')
print(flight_rows)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2007")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2135")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2262")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2387")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2512")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2675")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2801")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.2931")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3061")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3228")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3354")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3480")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3606")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3783")>, <selenium.webdriver.remote.webelement.WebElement (session="051ace7c497545d16420037cd67ee81f", element="f.272A0510CCF30122D61F31E6DA04E9F4.d.34A2D24206491B084530BDFEF8EB64C4.e.3913")>]

# %%
lst_prices =[]

# %%
for WebElement in flight_rows:
    elementHTML = WebElement.get_attribute('outerHTML')
    elementSoup = Soup(elementHTML, 'lxml')

    # Now continue can be used properly within the loop
    try:
        # Your parsing code goes here
        # For example:
        temp_price = elementSoup.find("div", {"class": 'nrc6-price-section'})
        temp_airline = elementSoup.find("div", {"class": 'nrc6-default-footer'})
        temp_duration = elementSoup.find("div", {"class": 'nrc6-main'})
        #temp_stop = elementSoup.find("div", {"class": 'hJSA'})
        
        price = temp_price.find("div", {"class": "f8F1-price-text"})
        airline = temp_airline.find("div", {"class": "J0g6-operator-text"})
        duration = temp_duration.find("div", {"class": "xdW8 xdW8-mod-full-airport"})
        stop = temp_duration.find("span", {"class": "JWEO-stops-text"})
        time = temp_duration.find("div", {"class": "vmXl vmXl-mod-variant-large"})
        where_stop = temp_duration.find("div", {"class": ""})
        
        lst_prices.append(price.text)
        lst_prices.append(airline.text)
        lst_prices.append(duration.text)
        lst_prices.append(stop.text)
        lst_prices.append(time.text)
        pass
    except AttributeError:
        print("Attribute error occurred, skipping this element.")
        continue  # Move to the next iteration of the loop if there's an attribute error

# %%
print(lst_prices)

# %%
driver.quit()

# %%
lst_prices = []
lst_airline = []
lst_duration = []
lst_stop = []
lst_time = []

# %% [markdown]
# ---

# %%
def start_kayak(to_location, from_location, date_start):
    """City codes - it's the IATA codes!
    Date format -  YYYY-MM-DD"""

    driver = webdriver.Chrome()
    #to_location = 'AGP'
    #from_location = 'BLL'
    #date_start = '2024-08-03'
    url = 'https://www.kayak.dk/flights/{from_location}-{to_location}/{date_start}-flexible-2days/2adults?fs=cfc=1&sort=bestflight_a'.format(to_location=to_location, from_location=from_location, date_start=date_start)
    driver.get(url)
    sleep(10)
    
#Click on the popup window:
    driver.find_element("xpath", '//*[@id="portal-container"]/div/div[2]/div/div/div[1]/div/span[2]/button').click()
    print('Popup closed.....')
    sleep(5)

    #Click on the 'load more' button in the end of the page:
    driver.find_element(By.CLASS_NAME, 'ULvh').click()
    print('sleeping.....')
    sleep(5)
    
    #Start the first scrape
    print('starting first scrape.....')
    flight_rows = driver.find_elements(By.XPATH, '//div[@class="nrc6-wrapper"]')
    print('Found WebElements')
    sleep(5)
    
#Scrape through the WebElements from flight rows and extract desired data
    for WebElement in flight_rows:
        elementHTML = WebElement.get_attribute('outerHTML')
        elementSoup = Soup(elementHTML, 'lxml')

        try:
            # Your parsing code goes here
            # For example:
            temp_price = elementSoup.find("div", {"class": 'nrc6-price-section'})
            temp_airline = elementSoup.find("div", {"class": 'nrc6-default-footer'})
            temp_duration = elementSoup.find("div", {"class": 'nrc6-main'})
            #temp_stop = elementSoup.find("div", {"class": 'hJSA'})
        
            price = temp_price.find("div", {"class": "f8F1-price-text"})
            airline = temp_airline.find("div", {"class": "J0g6-operator-text"})
            duration = temp_duration.find("div", {"class": "xdW8 xdW8-mod-full-airport"})
            stop = temp_duration.find("span", {"class": "JWEO-stops-text"})
            time = temp_duration.find("div", {"class": "vmXl vmXl-mod-variant-large"})
            #where_stop = temp_duration.find("div", {"class": ""})

            #lst_prices.append([price, airline, duration, stop, time])
            lst_prices.append(price.text)
            lst_airline.append(airline.text)
            lst_duration.append(duration.text)
            lst_stop.append(stop.text)
            lst_time.append(time.text)
        except AttributeError:
            print("Attribute error occurred, skipping this element.")
            continue  # Move to the next iteration of the loop if there's an attribute error

    cols = ['Price', 'Airline', 'Out Duration', 'Stops', 'Time']
    
    flights_df = pd.DataFrame({
    'Price': lst_prices,
    'Airline': lst_airline,
    'Out Duration': lst_duration,
    'Stops': lst_stop,
    'Time': lst_time
    })
    
    flights_df = flights_df[cols]
    flights_df['timestamp'] = strftime("%Y%m%d-%H%M")
    
    sleep(5)
    print("Job's Done!")

# %%
to_location = 'AGP'
from_location = 'BLL'
date_start = '2024-08-03'

start_kayak(to_location, from_location, date_start)
# Out:
# Popup closed.....
# sleeping.....
# starting first scrape.....
# Found WebElements
# Job's Done!

# %%
cols = ['Price', 'Airline', 'Out Duration', 'Stops', 'Time']
flights_df = pd.DataFrame({
    'Price': lst_prices,
    'Airline': lst_airline,
    'Out Duration': lst_duration,
    'Stops': lst_stop,
    'Time': lst_time
})
flights_df = flights_df[cols]
flights_df['timestamp'] = strftime("%Y%m%d-%H%M")
flights_df
# Out:
#         Price          Airline Out Duration   Stops             Time  \
# 0   1.080 kr.              KLM   7t. 00min.  1 stop    14:20 – 21:20
# 1   1.304 kr.              KLM   6t. 10min.  1 stop    14:20 – 20:30
# 2   1.304 kr.              KLM   6t. 35min.  1 stop    13:35 – 20:10
# 3   1.376 kr.        Lufthansa   5t. 25min.  1 stop    06:05 – 11:30
# 4   1.080 kr.              KLM   9t. 05min.  1 stop    12:15 – 21:20
# 5   1.081 kr.              KLM   8t. 40min.  1 stop    13:35 – 22:15
# 6   1.081 kr.              KLM  10t. 05min.  1 stop    12:10 – 22:15
# 7   1.089 kr.              KLM  12t. 10min.  1 stop    10:05 – 22:15
# 8   1.187 kr.              KLM  11t. 15min.  1 stop    10:05 – 21:20
# 9   1.304 kr.              KLM   8t. 15min.  1 stop    12:15 – 20:30
# 10  1.304 kr.              KLM   9t. 05min.  1 stop    11:05 – 20:10
# 11  1.304 kr.              KLM  10t. 05min.  1 stop    10:05 – 20:10
# 12  1.304 kr.              KLM  10t. 25min.  1 stop    10:05 – 20:30
# 13  1.319 kr.              KLM  13t. 30min.  1 stop  18:30 – 08:00+1
# 14  1.434 kr.              KLM  13t. 30min.  1 stop  18:30 – 08:00+1
# 15  1.435 kr.        Lufthansa   8t. 20min.  1 stop    14:50 – 23:10
# 16  1.435 kr.        Lufthansa  12t. 15min.  1 stop    10:55 – 23:10
# 17  1.443 kr.        Lufthansa   7t. 30min.  1 stop    06:10 – 13:40
# 18  1.489 kr.        Lufthansa  10t. 15min.  2 stop    13:05 – 23:20
# 19  1.512 kr.        Lufthansa  11t. 40min.  1 stop    06:10 – 17:50
# 20  1.512 kr.        Lufthansa  11t. 45min.  1 stop    06:05 – 17:50
# 21  1.568 kr.       Air France   9t. 00min.  2 stop    14:20 – 23:20
# 22  1.568 kr.       Air France   9t. 00min.  2 stop    14:20 – 23:20
# 23  1.574 kr.              KLM   6t. 35min.  1 stop    06:00 – 12:35
# 24  1.624 kr.        Lufthansa  10t. 50min.  2 stop    06:10 – 17:00
# 25  1.629 kr.  KLM, Air Europa  10t. 15min.  2 stop    06:00 – 16:15
# 26  1.647 kr.       Air France   9t. 00min.  2 stop    14:20 – 23:20
# 27  1.656 kr.              KLM   6t. 35min.  1 stop    06:00 – 12:35
# 28  1.656 kr.              KLM   7t. 30min.  1 stop    12:10 – 19:40
# 29  1.688 kr.              KLM   9t. 35min.  1 stop    10:05 – 19:40
#
#         timestamp
# 0   20240411-1031
# 1   20240411-1031
# 2   20240411-1031
# 3   20240411-1031
# 4   20240411-1031
# 5   20240411-1031
# 6   20240411-1031
# 7   20240411-1031
# 8   20240411-1031
# 9   20240411-1031
# 10  20240411-1031
# 11  20240411-1031
# 12  20240411-1031
# 13  20240411-1031
# 14  20240411-1031
# 15  20240411-1031
# 16  20240411-1031
# 17  20240411-1031
# 18  20240411-1031
# 19  20240411-1031
# 20  20240411-1031
# 21  20240411-1031
# 22  20240411-1031
# 23  20240411-1031
# 24  20240411-1031
# 25  20240411-1031
# 26  20240411-1031
# 27  20240411-1031
# 28  20240411-1031
# 29  20240411-1031

# %%
#Clean up the data a little bit
flights_df['Price'] = pd.to_numeric(flights_df['Price'].str.replace('.', '').str.replace('kr', '').str.strip())
airline_list = flights_df['Airline'].tolist()
flights_df['Price']
# Out:
# 0     1080
# 1     1375
# 2     1080
# 3     1081
# 4     1081
# 5     1138
# 6     1153
# 7     1186
# 8     1260
# 9     1304
# 10    1304
# 11    1304
# 12    1326
# 13    1326
# 14    1443
# 15    1568
# 16    1626
# 17    1650
# 18    1658
# 19    1687
# 20    1722
# 21    1736
# 22    1749
# 23    1755
# 24    1768
# 25    1768
# 26    1769
# 27    1780
# 28    1789
# 29    1802
# Name: Price, dtype: int64

# %%
airline_list = flights_df['Airline'].tolist()

# %% [markdown]
# With this in mind, you can scrape almost any webpage of interest. Other formats such as <a href="http://www.json.org/" target="_blank">JSON</a> and <a href="https://www.w3.org/XML/" target="_blank">XML</a> do have high similarities and a few differences.

# %% [markdown]
# ***But keep in mind that you should act politely, with propoer permission!! To find out whether specific paths/contents are allowed to be scraped, you can check their ___`robots.txt`___. For example, <a href="https://www.google.com/robots.txt" target="_blank">here's</a> the permission information set by Google.***

# %% [markdown]
# ---

# %% [markdown]
# Note that the examples we are using here are relatively simple. There are cases that we cannot access the pagination/scoll simply by `requests` alone. In those cases, [Selenium](http://selenium-python.readthedocs.io/) will save our lifes by ___simulating Browsers___!

# %% [markdown]
# Some more tutorials/tools:
#
# - https://scrapy.org/ #building a crawler
# - https://www.dataquest.io/blog/web-scraping-tutorial-python/
# - https://www.quora.com/Python-programming-language-1/How-is-BeautifulSoup-different-from-Scrapy

# %% [markdown]
# ---
#
# return to [overview](../00_overview.ipynb)
