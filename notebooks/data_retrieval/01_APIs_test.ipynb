# %% [markdown]
# # APIs for data retrieval

# %% [markdown]
# An Application Programming Interface, commonly known as API, is a set of protocols, routines, and tools for building software applications. APIs allow different software systems to communicate with each other and exchange data in a standardized and efficient way.
#
# APIs for retrieving data enable developers to access and extract information from various sources such as databases, web services, or applications. These APIs often provide a structured and consistent way of accessing data, making it easier for developers to consume and use the data in their applications.
#
# APIs for retrieving data can be used for a variety of purposes, such as gathering information for business intelligence, analyzing user behavior, or integrating data from different sources into a single application. These APIs often use standardized data formats, such as JSON or XML, to ensure compatibility and interoperability between different systems.
#
# As the amount of data available online continues to grow, APIs for retrieving data have become an essential tool for developers to access and analyze this data. By leveraging these APIs, developers can quickly and easily retrieve the data they need, without having to manually extract and process it themselves.

# %% [markdown]
# ### API types
# There are several types of APIs available, but two of the most commonly used types are REST API and HTTP API.
#
# - REST API (Representational State Transfer API):
# REST stands for Representational State Transfer, and it's a set of architectural principles for building web services. A REST API is a type of web service that follows the REST architecture principles. REST APIs use HTTP methods (GET, POST, PUT, DELETE, etc.) to access and manipulate resources, which are identified by URIs (Uniform Resource Identifiers). REST APIs typically return data in JSON or XML format and are widely used for building web and mobile applications.
#
#
# - HTTP API (Hypertext Transfer Protocol API):
# HTTP stands for Hypertext Transfer Protocol, which is the protocol used for transferring data over the World Wide Web. An HTTP API is a type of web service that uses HTTP methods to access and manipulate resources. An HTTP API can be RESTful, but it doesn't have to be. HTTP APIs are often used for simple operations like CRUD (Create, Read, Update, Delete) on resources and return data in JSON or XML format.
#
#
# Other types of APIs include SOAP (Simple Object Access Protocol), GraphQL, and WebSockets. SOAP is an older protocol used for building web services, while GraphQL is a newer API technology that allows clients to specify the data they need and receive it in a single request. WebSockets are used for real-time, two-way communication between a client and a server.

# %% [markdown]
# ### python and APIs

# %% [markdown]
# Python is a popular programming language that provides powerful tools for interacting with APIs. Here are the steps to interact with APIs using Python:
#
# 1. Import the necessary libraries: Python has several libraries that make it easy to interact with APIs, including requests, json, and urllib. Before making any API requests, you need to import the appropriate libraries.
#
# 2. Find the API endpoint: The endpoint is the URL that you will use to send your API requests. It's essential to understand the API documentation to find the correct endpoint for the specific data you want to retrieve.
#
# 3. Send a request: Once you have the endpoint, you can use Python's requests library to send an HTTP request to the API endpoint. The requests library has several methods for sending different types of HTTP requests, including GET, POST, PUT, DELETE, and more.
#
# 4. Parse the response: The API response will typically be in JSON format. Python's json library can be used to parse the JSON data and convert it into a Python dictionary that you can easily work with in your code.
#
# 5. Extract the data: Once you have the API response in a Python dictionary, you can extract the data you need and use it in your application.
#
# Python's ease of use and powerful libraries make it an excellent language for interacting with APIs. With just a few lines of code, you can send requests to APIs, parse the response data, and extract the information you need to build powerful applications.

# %% [markdown]
# ### Using the request package

# %% [markdown]
# To do this, we need to know how to send requests first. We will use an amazing package called [`requests`](http://docs.python-requests.org/en/master/). If you do not have it installed, please install it using e.g. `pip` (in your command prompt or terminal):
#
#
# ```$ pip install requests```

# %%
pip install requests pandas datetime
# Out:
# Requirement already satisfied: requests in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (2.31.0)
# Collecting pandas
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from requests) (2024.2.2)
# Collecting numpy<2,>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-6.2-cp311-cp311-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from zope.interface->datetime) (69.1.0)
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 16.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.4/11.6 MB 15.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.9/11.6 MB 20.8 MB/s eta 0:00:01
#    --------------- ------------------------ 4.6/11.6 MB 24.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 26.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.6 MB 28.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.6 MB 30.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 36.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 36.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 36.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 27.3 MB/s eta 0:00:00
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.6 kB ? eta -:--:--
#    ---------------------------------------- 52.6/52.6 kB ? eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.4/15.8 MB 45.3 MB/s eta 0:00:01
#    -------- ------------------------------- 3.4/15.8 MB 43.3 MB/s eta 0:00:01
#    ------------ --------------------------- 5.1/15.8 MB 40.7 MB/s eta 0:00:01
#    ------------------ --------------------- 7.2/15.8 MB 42.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/15.8 MB 42.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.8 MB 43.7 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.8 MB 38.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.8 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 28.5 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Downloading zope.interface-6.2-cp311-cp311-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.3 kB ? eta -:--:--
#    --------------------------------------- 204.3/204.3 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: pytz, zope.interface, tzdata, numpy, pandas, datetime
# Successfully installed datetime-5.5 numpy-1.26.4 pandas-2.2.1 pytz-2024.1 tzdata-2024.1 zope.interface-6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests # library for making HTTP requests
import pandas as pd # library for data analysis
import datetime as dt # library for handling date and time objects

# %% [markdown]
# ###### open DMI weather data
#
# Go to the [documentation](https://confluence.govcloud.dk/display/FDAPI/Danish+Meteorological+Institute+-+Open+Data)
#
# Using weather as an example, we should first know what is the request URL (where the request goes to), with what parameters(e.g., API key and stationID). In our case, we know that our API key and the stationId to query so we can do the following.
#
# You will have to create a user and retrieve an API key for the API you want to use [how to](https://confluence.govcloud.dk/display/FDAPI/User+Creation)
#
# I have saved my API key in an file ```.env```
#
#     api_key = your_api_key
#
# Specifically we will look at [Meteorological Observation](https://confluence.govcloud.dk/display/FDAPI/Meteorological+Observation)

# %%
# Read the keys and tokens into a dictionary
my_dict = {}

with open(r"C:\Users\Christian\Documents\Cand. merc\Data-Science-Project\Data-Science-Project\.env", "r") as f:
    for line in f:
        key, val = line.split('=')
        my_dict[key.strip()] = val.strip()

# %%
querystring = {"origin":"HKT","page":"None","currency":"EUR","destination":"-"}

# %%
headers = {
	"X-Access-Token": "be1cddabbc29289e57cfe5010ac3f063",
	"X-RapidAPI-Key": "c795ba9581msh07d0178516af21bp1d788bjsnd4de235dbca6",
	"X-RapidAPI-Host": "travelpayouts-travelpayouts-flight-data-v1.p.rapidapi.com"
}

# %%
url = "https://travelpayouts-travelpayouts-flight-data-v1.p.rapidapi.com/v1/prices/cheap"
r = requests.get(url, headers=headers, params=querystring) # Issues a HTTP GET request
print(r)
# Out:
# <Response [200]>

# %%
ticket = r.json()  # Extract JSON data
ticket  # Print the keys of the JSON dictionary
# Out:
# {'data': {'AER': {'2': {'airline': 'CA',
#     'departure_at': '2024-05-01T19:30:00+07:00',
#     'return_at': '2024-05-03T13:05:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 774,
#     'flight_number': 822}},
#   'AKL': {'2': {'airline': 'MU',
#     'departure_at': '2024-04-10T18:55:00+07:00',
#     'return_at': '2024-04-24T21:00:00+12:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 592,
#     'flight_number': 5094}},
#   'AKX': {'4': {'airline': 'VJ',
#     'departure_at': '2024-04-21T11:55:00+07:00',
#     'return_at': '2024-05-12T01:55:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 880,
#     'flight_number': 808}},
#   'ALA': {'1': {'airline': 'AK',
#     'departure_at': '2024-05-31T21:40:00+07:00',
#     'return_at': '2024-06-23T19:00:00+06:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 528,
#     'flight_number': 823}},
#   'AMM': {'1': {'airline': 'G9',
#     'departure_at': '2024-04-08T09:15:00+07:00',
#     'return_at': '2024-04-28T16:25:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 697,
#     'flight_number': 688}},
#   'AMS': {'3': {'airline': 'FD',
#     'departure_at': '2024-04-27T22:15:00+07:00',
#     'return_at': '2024-05-11T14:00:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 908,
#     'flight_number': 4113}},
#   'ANU': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-27T23:25:00+07:00',
#     'return_at': '2024-06-03T13:25:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 2024,
#     'flight_number': 841}},
#   'ASF': {'2': {'airline': 'QR',
#     'departure_at': '2024-06-03T09:05:00+07:00',
#     'return_at': '2024-06-30T14:45:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 994,
#     'flight_number': 843}},
#   'AUA': {'2': {'airline': 'AI',
#     'departure_at': '2024-04-12T09:15:00+07:00',
#     'return_at': '2024-04-27T17:20:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1930,
#     'flight_number': 379}},
#   'AYT': {'2': {'airline': '6E',
#     'departure_at': '2024-04-11T00:15:00+07:00',
#     'return_at': '2024-04-11T22:10:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 725,
#     'flight_number': 1912}},
#   'BAK': {'2': {'airline': 'VZ',
#     'departure_at': '2024-04-15T08:55:00+07:00',
#     'return_at': '2024-04-17T16:55:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 827,
#     'flight_number': 315}},
#   'BAX': {'1': {'airline': 'SU',
#     'departure_at': '2024-05-28T09:25:00+07:00',
#     'return_at': '2024-06-22T14:20:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 918,
#     'flight_number': 637}},
#   'BCN': {'1': {'airline': 'EY',
#     'departure_at': '2024-06-05T08:55:00+07:00',
#     'return_at': '2024-06-14T21:50:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 754,
#     'flight_number': 433}},
#   'BEG': {'3': {'airline': 'OV',
#     'departure_at': '2024-04-17T23:15:00+07:00',
#     'return_at': '2024-04-21T05:30:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 791,
#     'flight_number': 486}},
#   'BER': {'2': {'airline': 'EY',
#     'departure_at': '2024-07-01T08:55:00+07:00',
#     'return_at': '2024-07-07T11:35:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1072,
#     'flight_number': 433}},
#   'BJS': {'1': {'airline': 'CZ',
#     'departure_at': '2024-06-13T23:15:00+07:00',
#     'return_at': '2024-06-17T12:30:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 203,
#     'flight_number': 6058}},
#   'BJV': {'3': {'airline': 'AK',
#     'departure_at': '2024-06-03T21:40:00+07:00',
#     'return_at': '2024-06-23T23:05:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 878,
#     'flight_number': 823}},
#   'BKI': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-24T12:00:00+07:00',
#     'return_at': '2024-05-01T07:00:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 198,
#     'flight_number': 833}},
#   'BKK': {'0': {'airline': 'FD',
#     'departure_at': '2024-05-13T22:25:00+07:00',
#     'return_at': '2024-05-28T22:15:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 41,
#     'flight_number': 3014}},
#   'BLR': {'1': {'airline': 'MH',
#     'departure_at': '2024-05-31T10:30:00+07:00',
#     'return_at': '2024-06-12T00:40:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 310,
#     'flight_number': 787}},
#   'BNE': {'2': {'airline': 'AK',
#     'departure_at': '2024-04-08T21:40:00+07:00',
#     'return_at': '2024-04-13T20:45:00+10:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 548,
#     'flight_number': 823}},
#   'BOD': {'2': {'airline': 'QR',
#     'departure_at': '2024-06-05T09:05:00+07:00',
#     'return_at': '2024-06-08T17:55:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 979,
#     'flight_number': 843}},
#   'BOG': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-18T23:25:00+07:00',
#     'return_at': '2024-05-26T21:44:00-05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1740,
#     'flight_number': 841}},
#   'BOM': {'1': {'airline': 'MH',
#     'departure_at': '2024-05-15T14:05:00+07:00',
#     'return_at': '2024-05-18T23:25:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 302,
#     'flight_number': 795}},
#   'BPN': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-09T21:40:00+07:00',
#     'return_at': '2024-04-14T12:30:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 306,
#     'flight_number': 823}},
#   'BQS': {'1': {'airline': 'SU',
#     'departure_at': '2024-05-26T15:15:00+07:00',
#     'return_at': '2024-05-30T12:55:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 812,
#     'flight_number': 642}},
#   'BUE': {'1': {'airline': 'TK',
#     'departure_at': '2024-05-20T22:15:00+07:00',
#     'return_at': '2024-05-31T23:55:00-03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1617,
#     'flight_number': 173}},
#   'BUH': {'3': {'airline': 'OV',
#     'departure_at': '2024-05-28T11:20:00+07:00',
#     'return_at': '2024-06-07T06:15:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 823,
#     'flight_number': 482}},
#   'BUS': {'2': {'airline': 'TK',
#     'departure_at': '2024-06-11T19:10:00+07:00',
#     'return_at': '2024-06-18T10:35:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 846,
#     'flight_number': 4482}},
#   'BWI': {'2': {'airline': 'QR',
#     'departure_at': '2024-04-27T23:25:00+07:00',
#     'return_at': '2024-05-11T17:20:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1508,
#     'flight_number': 841}},
#   'BWN': {'1': {'airline': 'AK',
#     'departure_at': '2024-06-25T21:40:00+07:00',
#     'return_at': '2024-06-26T16:10:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 231,
#     'flight_number': 823}},
#   'CAI': {'2': {'airline': '6E',
#     'departure_at': '2024-05-08T00:15:00+07:00',
#     'return_at': '2024-05-08T16:25:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 874,
#     'flight_number': 1912}},
#   'CAN': {'0': {'airline': '9C',
#     'departure_at': '2024-05-08T20:55:00+07:00',
#     'return_at': '2024-05-25T05:55:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 190,
#     'flight_number': 8772}},
#   'CCC': {'2': {'airline': 'AI',
#     'departure_at': '2024-04-13T09:15:00+07:00',
#     'return_at': '2024-04-26T21:40:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 9441,
#     'flight_number': 379}},
#   'CEB': {'1': {'airline': 'TR',
#     'departure_at': '2024-05-21T20:00:00+07:00',
#     'return_at': '2024-06-04T01:10:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 230,
#     'flight_number': 653}},
#   'CEI': {'0': {'airline': 'VZ',
#     'departure_at': '2024-04-26T08:15:00+07:00',
#     'return_at': '2024-04-29T10:55:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 114,
#     'flight_number': 400}},
#   'CEK': {'2': {'airline': '3U',
#     'departure_at': '2024-04-24T19:30:00+07:00',
#     'return_at': '2024-05-05T07:20:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 872,
#     'flight_number': 3932}},
#   'CGN': {'3': {'airline': 'AK',
#     'departure_at': '2024-04-30T21:40:00+07:00',
#     'return_at': '2024-05-11T22:20:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 890,
#     'flight_number': 823}},
#   'CMB': {'1': {'airline': 'AK',
#     'departure_at': '2024-06-09T21:40:00+07:00',
#     'return_at': '2024-06-11T22:55:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 294,
#     'flight_number': 823}},
#   'CMN': {'1': {'airline': 'EK',
#     'departure_at': '2024-05-14T23:55:00+07:00',
#     'return_at': '2024-05-21T14:55:00+01:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 976,
#     'flight_number': 397}},
#   'CNX': {'0': {'airline': 'VZ',
#     'departure_at': '2024-06-17T08:05:00+07:00',
#     'return_at': '2024-06-24T15:30:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 111,
#     'flight_number': 415}},
#   'CPH': {'3': {'airline': 'OV',
#     'departure_at': '2024-04-10T23:15:00+07:00',
#     'return_at': '2024-04-27T06:05:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 826,
#     'flight_number': 486}},
#   'CPT': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-28T19:10:00+07:00',
#     'return_at': '2024-05-04T13:50:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1085,
#     'flight_number': 4382}},
#   'CTU': {'0': {'airline': 'CA',
#     'departure_at': '2024-05-08T14:00:00+07:00',
#     'return_at': '2024-05-19T05:05:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 264,
#     'flight_number': 414}},
#   'CUN': {'1': {'airline': 'TK',
#     'departure_at': '2024-05-15T22:15:00+07:00',
#     'return_at': '2024-05-22T14:00:00-05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1245,
#     'flight_number': 173}},
#   'DAC': {'1': {'airline': 'MH',
#     'departure_at': '2024-04-27T14:05:00+07:00',
#     'return_at': '2024-05-04T02:05:00+06:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 337,
#     'flight_number': 795}},
#   'DAD': {'1': {'airline': 'VZ',
#     'departure_at': '2024-05-08T08:55:00+07:00',
#     'return_at': '2024-05-14T18:10:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 175,
#     'flight_number': 315}},
#   'DED': {'3': {'airline': 'TR',
#     'departure_at': '2024-04-06T20:00:00+07:00',
#     'return_at': '2024-04-23T20:05:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 497,
#     'flight_number': 653}},
#   'DEL': {'2': {'airline': 'AK',
#     'departure_at': '2024-04-22T12:00:00+07:00',
#     'return_at': '2024-05-06T23:20:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 280,
#     'flight_number': 833}},
#   'DLC': {'1': {'airline': 'CZ',
#     'departure_at': '2024-05-10T23:30:00+07:00',
#     'return_at': '2024-05-19T07:25:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 261,
#     'flight_number': 6058}},
#   'DLI': {'1': {'airline': 'VJ',
#     'departure_at': '2024-04-26T11:55:00+07:00',
#     'return_at': '2024-04-28T18:55:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 331,
#     'flight_number': 808}},
#   'DLM': {'3': {'airline': 'AK',
#     'departure_at': '2024-05-08T21:40:00+07:00',
#     'return_at': '2024-05-13T22:40:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 829,
#     'flight_number': 823}},
#   'DOH': {'1': {'airline': 'G9',
#     'departure_at': '2024-05-02T08:45:00+07:00',
#     'return_at': '2024-05-09T09:55:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 590,
#     'flight_number': 688}},
#   'DOM': {'3': {'airline': 'EY',
#     'departure_at': '2024-04-21T20:55:00+07:00',
#     'return_at': '2024-04-28T07:00:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 4547,
#     'flight_number': 431}},
#   'DPS': {'1': {'airline': 'AK',
#     'departure_at': '2024-05-22T21:40:00+07:00',
#     'return_at': '2024-05-29T07:00:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 162,
#     'flight_number': 823}},
#   'DUS': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-15T17:30:00+07:00',
#     'return_at': '2024-04-26T07:20:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1318,
#     'flight_number': 4480}},
#   'DXB': {'1': {'airline': 'MU',
#     'departure_at': '2024-05-10T00:20:00+07:00',
#     'return_at': '2024-05-16T10:40:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 476,
#     'flight_number': 8618}},
#   'DYG': {'1': {'airline': 'FM',
#     'departure_at': '2024-05-18T00:20:00+07:00',
#     'return_at': '2024-05-21T23:20:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 284,
#     'flight_number': 832}},
#   'DYU': {'2': {'airline': '6E',
#     'departure_at': '2024-04-28T13:30:00+07:00',
#     'return_at': '2024-05-03T12:40:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1083,
#     'flight_number': 1074}},
#   'ECN': {'2': {'airline': 'AK',
#     'departure_at': '2024-04-30T21:40:00+07:00',
#     'return_at': '2024-05-13T22:00:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 764,
#     'flight_number': 823}},
#   'EVN': {'3': {'airline': 'AK',
#     'departure_at': '2024-04-24T12:00:00+07:00',
#     'return_at': '2024-04-28T10:15:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 714,
#     'flight_number': 833}},
#   'FRA': {'1': {'airline': 'FM',
#     'departure_at': '2024-04-22T00:20:00+07:00',
#     'return_at': '2024-05-05T14:30:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 724,
#     'flight_number': 8618}},
#   'FRS': {'3': {'airline': 'KE',
#     'departure_at': '2024-06-16T23:40:00+07:00',
#     'return_at': '2024-06-23T07:40:00-06:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 7778,
#     'flight_number': 664}},
#   'FRU': {'3': {'airline': '3K',
#     'departure_at': '2024-04-23T21:20:00+07:00',
#     'return_at': '2024-04-30T15:15:00+06:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 651,
#     'flight_number': 538}},
#   'FUK': {'1': {'airline': 'FD',
#     'departure_at': '2024-06-02T11:40:00+07:00',
#     'return_at': '2024-06-30T08:55:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 256,
#     'flight_number': 9161}},
#   'GDX': {'1': {'airline': 'SU',
#     'departure_at': '2024-05-15T17:55:00+07:00',
#     'return_at': '2024-06-01T16:20:00+11:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1092,
#     'flight_number': 642}},
#   'GNJ': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-21T09:05:00+07:00',
#     'return_at': '2024-05-30T12:00:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1190,
#     'flight_number': 843}},
#   'GOI': {'1': {'airline': '6E',
#     'departure_at': '2024-05-03T00:15:00+07:00',
#     'return_at': '2024-05-11T20:55:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 346,
#     'flight_number': 1912}},
#   'GVA': {'2': {'airline': 'PG',
#     'departure_at': '2024-05-04T19:10:00+07:00',
#     'return_at': '2024-05-18T10:40:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 800,
#     'flight_number': 278}},
#   'GZP': {'2': {'airline': '6E',
#     'departure_at': '2024-04-24T00:15:00+07:00',
#     'return_at': '2024-04-30T10:30:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 744,
#     'flight_number': 1912}},
#   'HAK': {'1': {'airline': 'CZ',
#     'departure_at': '2024-04-13T16:40:00+07:00',
#     'return_at': '2024-05-10T10:00:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 331,
#     'flight_number': 6064}},
#   'HAN': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-09T08:15:00+07:00',
#     'return_at': '2024-05-24T20:55:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 206,
#     'flight_number': 3002}},
#   'HAV': {'2': {'airline': 'QR',
#     'departure_at': '2024-04-21T23:25:00+07:00',
#     'return_at': '2024-04-28T18:45:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 3229,
#     'flight_number': 841}},
#   'HDY': {'0': {'airline': 'PG',
#     'departure_at': '2024-05-19T07:30:00+07:00',
#     'return_at': '2024-05-26T09:15:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 76,
#     'flight_number': 298}},
#   'HEK': {'1': {'airline': 'FM',
#     'departure_at': '2024-04-24T23:05:00+07:00',
#     'return_at': '2024-05-05T14:50:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 630,
#     'flight_number': 858}},
#   'HEL': {'1': {'airline': 'HO',
#     'departure_at': '2024-05-11T23:30:00+07:00',
#     'return_at': '2024-05-28T16:55:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 804,
#     'flight_number': 1370}},
#   'HGH': {'1': {'airline': 'CZ',
#     'departure_at': '2024-06-28T23:15:00+07:00',
#     'return_at': '2024-07-10T21:35:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 239,
#     'flight_number': 6058}},
#   'HHQ': {'1': {'airline': 'VZ',
#     'departure_at': '2024-05-18T08:05:00+07:00',
#     'return_at': '2024-05-20T12:20:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 175,
#     'flight_number': 415}},
#   'HKG': {'0': {'airline': 'HX',
#     'departure_at': '2024-05-08T21:00:00+07:00',
#     'return_at': '2024-05-14T17:15:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 137,
#     'flight_number': 742}},
#   'HRB': {'1': {'airline': 'CZ',
#     'departure_at': '2024-05-27T23:30:00+07:00',
#     'return_at': '2024-06-14T12:30:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 243,
#     'flight_number': 6058}},
#   'HRG': {'3': {'airline': '6E',
#     'departure_at': '2024-04-05T00:15:00+07:00',
#     'return_at': '2024-04-06T15:15:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 896,
#     'flight_number': 1912}},
#   'HTA': {'2': {'airline': 'CA',
#     'departure_at': '2024-05-13T19:30:00+07:00',
#     'return_at': '2024-05-19T04:10:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 750,
#     'flight_number': 822}},
#   'IDR': {'2': {'airline': 'AK',
#     'departure_at': '2024-05-05T21:40:00+07:00',
#     'return_at': '2024-05-11T19:55:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 341,
#     'flight_number': 823}},
#   'IJK': {'2': {'airline': 'FM',
#     'departure_at': '2024-06-23T00:20:00+07:00',
#     'return_at': '2024-06-24T17:25:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 879,
#     'flight_number': 8618}},
#   'IKT': {'2': {'airline': 'CZ',
#     'departure_at': '2024-04-10T16:40:00+07:00',
#     'return_at': '2024-04-13T06:30:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 551,
#     'flight_number': 6064}},
#   'IST': {'1': {'airline': 'MU',
#     'departure_at': '2024-06-03T23:05:00+07:00',
#     'return_at': '2024-06-07T14:00:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 495,
#     'flight_number': 8648}},
#   'JED': {'3': {'airline': 'OV',
#     'departure_at': '2024-04-21T23:15:00+07:00',
#     'return_at': '2024-04-26T14:10:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 621,
#     'flight_number': 486}},
#   'JHB': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-09T21:40:00+07:00',
#     'return_at': '2024-04-12T22:50:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 197,
#     'flight_number': 823}},
#   'JKT': {'1': {'airline': 'TR',
#     'departure_at': '2024-04-24T20:00:00+07:00',
#     'return_at': '2024-04-26T06:35:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 152,
#     'flight_number': 653}},
#   'JNB': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-21T14:45:00+07:00',
#     'return_at': '2024-05-01T09:55:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 908,
#     'flight_number': 274}},
#   'KBR': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-06T21:40:00+07:00',
#     'return_at': '2024-04-09T09:55:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 321,
#     'flight_number': 823}},
#   'KBV': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-16T22:15:00+07:00',
#     'return_at': '2024-05-24T16:40:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 131,
#     'flight_number': 4113}},
#   'KCH': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-24T21:40:00+07:00',
#     'return_at': '2024-04-28T23:45:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 169,
#     'flight_number': 823}},
#   'KEJ': {'3': {'airline': 'VZ',
#     'departure_at': '2024-04-12T07:30:00+07:00',
#     'return_at': '2024-04-26T07:40:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 922,
#     'flight_number': 317}},
#   'KGD': {'2': {'airline': 'FM',
#     'departure_at': '2024-05-14T00:20:00+07:00',
#     'return_at': '2024-05-23T09:55:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 720,
#     'flight_number': 8618}},
#   'KHV': {'2': {'airline': 'CZ',
#     'departure_at': '2024-06-04T23:15:00+07:00',
#     'return_at': '2024-06-17T19:15:00+10:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 570,
#     'flight_number': 6058}},
#   'KJA': {'2': {'airline': 'CZ',
#     'departure_at': '2024-05-07T23:30:00+07:00',
#     'return_at': '2024-05-27T19:20:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 636,
#     'flight_number': 6058}},
#   'KKC': {'1': {'airline': 'SL',
#     'departure_at': '2024-04-09T09:20:00+07:00',
#     'return_at': '2024-04-14T12:55:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 180,
#     'flight_number': 751}},
#   'KOP': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-06T08:15:00+07:00',
#     'return_at': '2024-05-09T16:50:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 145,
#     'flight_number': 3002}},
#   'KOS': {'2': {'airline': 'AK',
#     'departure_at': '2024-04-04T21:40:00+07:00',
#     'return_at': '2024-04-07T13:05:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 531,
#     'flight_number': 823}},
#   'KRK': {'2': {'airline': 'MU',
#     'departure_at': '2024-04-26T00:20:00+07:00',
#     'return_at': '2024-05-19T12:25:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 741,
#     'flight_number': 832}},
#   'KTM': {'1': {'airline': 'MH',
#     'departure_at': '2024-05-13T10:30:00+07:00',
#     'return_at': '2024-05-19T23:30:00+05:45',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 319,
#     'flight_number': 787}},
#   'KUF': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-09T23:25:00+07:00',
#     'return_at': '2024-05-15T12:00:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 826,
#     'flight_number': 841}},
#   'KUL': {'0': {'airline': 'AK',
#     'departure_at': '2024-06-13T21:40:00+07:00',
#     'return_at': '2024-06-15T20:40:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 80,
#     'flight_number': 823}},
#   'KZN': {'1': {'airline': 'G9',
#     'departure_at': '2024-04-25T08:45:00+07:00',
#     'return_at': '2024-05-14T23:45:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 733,
#     'flight_number': 688}},
#   'LAX': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-23T23:25:00+07:00',
#     'return_at': '2024-06-05T23:59:00-07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1026,
#     'flight_number': 841}},
#   'LCA': {'2': {'airline': 'OV',
#     'departure_at': '2024-04-15T23:15:00+07:00',
#     'return_at': '2024-04-28T21:15:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 866,
#     'flight_number': 486}},
#   'LED': {'1': {'airline': 'FM',
#     'departure_at': '2024-04-25T00:20:00+07:00',
#     'return_at': '2024-05-25T23:15:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 507,
#     'flight_number': 8618}},
#   'LGK': {'1': {'airline': 'TR',
#     'departure_at': '2024-04-18T20:00:00+07:00',
#     'return_at': '2024-04-20T11:10:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 124,
#     'flight_number': 653}},
#   'LIM': {'2': {'airline': 'TK',
#     'departure_at': '2024-06-21T22:15:00+07:00',
#     'return_at': '2024-07-13T02:25:00-05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1980,
#     'flight_number': 173}},
#   'LIS': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-23T19:10:00+07:00',
#     'return_at': '2024-04-30T09:05:00+01:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 852,
#     'flight_number': 278}},
#   'LON': {'1': {'airline': 'FM',
#     'departure_at': '2024-06-01T00:20:00+07:00',
#     'return_at': '2024-06-09T11:35:00+01:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 703,
#     'flight_number': 8618}},
#   'LOP': {'1': {'airline': 'AK',
#     'departure_at': '2024-06-19T21:40:00+07:00',
#     'return_at': '2024-07-18T06:15:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 215,
#     'flight_number': 823}},
#   'LXA': {'1': {'airline': 'MU',
#     'departure_at': '2024-05-13T18:55:00+07:00',
#     'return_at': '2024-05-19T15:45:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 365,
#     'flight_number': 5094}},
#   'MAD': {'1': {'airline': 'FM',
#     'departure_at': '2024-04-12T00:20:00+07:00',
#     'return_at': '2024-04-26T23:25:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 951,
#     'flight_number': 8618}},
#   'MCX': {'2': {'airline': 'WY',
#     'departure_at': '2024-04-28T09:10:00+07:00',
#     'return_at': '2024-05-04T06:00:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 964,
#     'flight_number': 834}},
#   'MEL': {'1': {'airline': '3K',
#     'departure_at': '2024-05-23T16:00:00+07:00',
#     'return_at': '2024-05-30T12:45:00+10:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 397,
#     'flight_number': 536}},
#   'MES': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-20T21:40:00+07:00',
#     'return_at': '2024-04-28T11:15:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 179,
#     'flight_number': 823}},
#   'MEX': {'1': {'airline': 'TK',
#     'departure_at': '2024-05-15T22:15:00+07:00',
#     'return_at': '2024-05-22T09:00:00-05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1355,
#     'flight_number': 173}},
#   'MFM': {'1': {'airline': 'FD',
#     'departure_at': '2024-06-06T20:55:00+07:00',
#     'return_at': '2024-06-08T21:30:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 242,
#     'flight_number': 3010}},
#   'MIA': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-05T20:30:00+07:00',
#     'return_at': '2024-05-12T19:15:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1226,
#     'flight_number': 847}},
#   'MIL': {'1': {'airline': 'CA',
#     'departure_at': '2024-06-15T19:30:00+07:00',
#     'return_at': '2024-07-15T13:00:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 717,
#     'flight_number': 822}},
#   'MLA': {'2': {'airline': 'TR',
#     'departure_at': '2024-04-18T09:15:00+07:00',
#     'return_at': '2024-04-26T17:40:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1120,
#     'flight_number': 659}},
#   'MLE': {'1': {'airline': 'AK',
#     'departure_at': '2024-06-13T13:35:00+07:00',
#     'return_at': '2024-06-25T10:45:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 307,
#     'flight_number': 825}},
#   'MNL': {'1': {'airline': 'TR',
#     'departure_at': '2024-05-10T16:30:00+07:00',
#     'return_at': '2024-05-16T19:35:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 193,
#     'flight_number': 657}},
#   'MOW': {'2': {'airline': 'MU',
#     'departure_at': '2024-04-07T19:25:00+07:00',
#     'return_at': '2024-05-07T19:10:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 477,
#     'flight_number': 574}},
#   'MPH': {'2': {'airline': '3K',
#     'departure_at': '2024-05-20T21:20:00+07:00',
#     'return_at': '2024-05-24T07:20:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 294,
#     'flight_number': 538}},
#   'MQF': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-12T12:00:00+07:00',
#     'return_at': '2024-04-14T06:05:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1029,
#     'flight_number': 627}},
#   'MRU': {'1': {'airline': 'MH',
#     'departure_at': '2024-04-11T10:30:00+07:00',
#     'return_at': '2024-04-18T23:00:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1028,
#     'flight_number': 787}},
#   'MRV': {'2': {'airline': 'FM',
#     'departure_at': '2024-06-05T00:20:00+07:00',
#     'return_at': '2024-06-21T00:50:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 800,
#     'flight_number': 8618}},
#   'MSQ': {'2': {'airline': 'FM',
#     'departure_at': '2024-05-24T00:20:00+07:00',
#     'return_at': '2024-05-31T11:50:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 771,
#     'flight_number': 8618}},
#   'NAN': {'2': {'airline': 'AK',
#     'departure_at': '2024-05-22T21:40:00+07:00',
#     'return_at': '2024-06-19T16:45:00+12:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 856,
#     'flight_number': 823}},
#   'NHA': {'1': {'airline': 'AK',
#     'departure_at': '2024-05-17T21:40:00+07:00',
#     'return_at': '2024-05-23T12:00:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 207,
#     'flight_number': 823}},
#   'NOZ': {'2': {'airline': 'SU',
#     'departure_at': '2024-04-10T10:35:00+07:00',
#     'return_at': '2024-04-17T11:50:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 894,
#     'flight_number': 275}},
#   'NQZ': {'1': {'airline': 'CA',
#     'departure_at': '2024-06-13T19:30:00+07:00',
#     'return_at': '2024-06-19T23:20:00+06:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 638,
#     'flight_number': 822}},
#   'NYC': {'1': {'airline': 'CX',
#     'departure_at': '2024-04-17T18:30:00+07:00',
#     'return_at': '2024-04-21T10:00:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 927,
#     'flight_number': 778}},
#   'OGZ': {'2': {'airline': 'OD',
#     'departure_at': '2024-05-03T13:15:00+07:00',
#     'return_at': '2024-05-11T23:05:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 841,
#     'flight_number': 541}},
#   'OKA': {'1': {'airline': 'FM',
#     'departure_at': '2024-04-10T00:20:00+07:00',
#     'return_at': '2024-04-17T16:30:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 399,
#     'flight_number': 8618}},
#   'OMS': {'3': {'airline': '6E',
#     'departure_at': '2024-04-06T00:15:00+07:00',
#     'return_at': '2024-04-20T01:15:00+06:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 871,
#     'flight_number': 1912}},
#   'ONT': {'2': {'airline': 'PG',
#     'departure_at': '2024-05-23T21:55:00+07:00',
#     'return_at': '2024-06-05T16:25:00-07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1303,
#     'flight_number': 280}},
#   'OOL': {'2': {'airline': 'FD',
#     'departure_at': '2024-04-20T22:25:00+07:00',
#     'return_at': '2024-05-02T14:25:00+10:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 535,
#     'flight_number': 3014}},
#   'OSA': {'1': {'airline': 'CZ',
#     'departure_at': '2024-04-10T16:40:00+07:00',
#     'return_at': '2024-04-17T16:30:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 441,
#     'flight_number': 6064}},
#   'OVB': {'0': {'airline': 'SU',
#     'departure_at': '2024-04-23T09:25:00+07:00',
#     'return_at': '2024-05-12T05:40:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 631,
#     'flight_number': 637}},
#   'PAR': {'1': {'airline': 'MU',
#     'departure_at': '2024-05-16T00:20:00+07:00',
#     'return_at': '2024-05-23T21:20:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 581,
#     'flight_number': 8618}},
#   'PEE': {'3': {'airline': '6E',
#     'departure_at': '2024-04-09T00:15:00+07:00',
#     'return_at': '2024-04-30T07:05:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 926,
#     'flight_number': 1912}},
#   'PEN': {'0': {'airline': 'FY',
#     'departure_at': '2024-05-08T14:35:00+07:00',
#     'return_at': '2024-05-12T13:50:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 95,
#     'flight_number': 3601}},
#   'PER': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-30T21:40:00+07:00',
#     'return_at': '2024-05-11T21:35:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 267,
#     'flight_number': 823}},
#   'PES': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-12T12:00:00+07:00',
#     'return_at': '2024-04-20T11:10:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1174,
#     'flight_number': 627}},
#   'PFO': {'2': {'airline': 'QR',
#     'departure_at': '2024-05-01T23:25:00+07:00',
#     'return_at': '2024-05-08T20:35:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1165,
#     'flight_number': 841}},
#   'PGK': {'2': {'airline': 'OD',
#     'departure_at': '2024-05-16T13:15:00+07:00',
#     'return_at': '2024-05-18T11:45:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 311,
#     'flight_number': 541}},
#   'PKC': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-12T22:00:00+07:00',
#     'return_at': '2024-04-19T09:25:00+12:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 848,
#     'flight_number': 639}},
#   'PKV': {'2': {'airline': '6E',
#     'departure_at': '2024-04-11T13:30:00+07:00',
#     'return_at': '2024-04-20T10:30:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1114,
#     'flight_number': 1074}},
#   'PNH': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-10T22:15:00+07:00',
#     'return_at': '2024-05-12T19:10:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 180,
#     'flight_number': 4113}},
#   'PPS': {'2': {'airline': 'VZ',
#     'departure_at': '2024-04-12T22:00:00+07:00',
#     'return_at': '2024-04-15T23:45:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 476,
#     'flight_number': 309}},
#   'PQC': {'1': {'airline': 'FD',
#     'departure_at': '2024-06-18T22:15:00+07:00',
#     'return_at': '2024-06-22T11:45:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 202,
#     'flight_number': 4113}},
#   'PRI': {'3': {'airline': 'FD',
#     'departure_at': '2024-05-16T22:15:00+07:00',
#     'return_at': '2024-05-31T19:55:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1326,
#     'flight_number': 4113}},
#   'PTY': {'2': {'airline': 'EK',
#     'departure_at': '2024-05-18T19:55:00+07:00',
#     'return_at': '2024-05-31T18:33:00-05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1632,
#     'flight_number': 379}},
#   'PUS': {'1': {'airline': 'FM',
#     'departure_at': '2024-04-18T00:20:00+07:00',
#     'return_at': '2024-04-19T12:35:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 332,
#     'flight_number': 8618}},
#   'RAK': {'3': {'airline': 'VZ',
#     'departure_at': '2024-05-03T13:30:00+07:00',
#     'return_at': '2024-05-05T18:15:00+01:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1164,
#     'flight_number': 2303}},
#   'REK': {'2': {'airline': 'QR',
#     'departure_at': '2024-06-01T20:30:00+07:00',
#     'return_at': '2024-06-09T10:40:00Z',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 950,
#     'flight_number': 847}},
#   'RGK': {'2': {'airline': 'SU',
#     'departure_at': '2024-05-27T12:30:00+07:00',
#     'return_at': '2024-06-03T14:15:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 906,
#     'flight_number': 635}},
#   'RGN': {'1': {'airline': 'FD',
#     'departure_at': '2024-06-17T09:30:00+07:00',
#     'return_at': '2024-06-18T17:30:00+06:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 188,
#     'flight_number': 3030}},
#   'RIO': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-17T21:55:00+07:00',
#     'return_at': '2024-04-20T14:40:00-03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 2270,
#     'flight_number': 280}},
#   'RMO': {'2': {'airline': '6E',
#     'departure_at': '2024-04-08T00:15:00+07:00',
#     'return_at': '2024-05-08T12:00:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 799,
#     'flight_number': 1912}},
#   'ROM': {'1': {'airline': 'FM',
#     'departure_at': '2024-05-15T23:05:00+07:00',
#     'return_at': '2024-05-30T21:10:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 569,
#     'flight_number': 858}},
#   'SAI': {'1': {'airline': 'SL',
#     'departure_at': '2024-04-21T09:20:00+07:00',
#     'return_at': '2024-04-23T11:55:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 184,
#     'flight_number': 751}},
#   'SAO': {'1': {'airline': 'TK',
#     'departure_at': '2024-04-17T22:15:00+07:00',
#     'return_at': '2024-04-21T04:05:00-03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1922,
#     'flight_number': 173}},
#   'SCL': {'2': {'airline': 'FM',
#     'departure_at': '2024-04-11T00:20:00+07:00',
#     'return_at': '2024-04-16T22:55:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 2632,
#     'flight_number': 8618}},
#   'SCO': {'3': {'airline': '6E',
#     'departure_at': '2024-04-22T11:05:00+07:00',
#     'return_at': '2024-04-26T02:55:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 985,
#     'flight_number': 1072}},
#   'SDQ': {'2': {'airline': 'QR',
#     'departure_at': '2024-06-03T09:05:00+07:00',
#     'return_at': '2024-06-30T05:01:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1606,
#     'flight_number': 843}},
#   'SEL': {'1': {'airline': 'SL',
#     'departure_at': '2024-04-19T22:05:00+07:00',
#     'return_at': '2024-04-28T01:05:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 252,
#     'flight_number': 763}},
#   'SEZ': {'2': {'airline': 'TG',
#     'departure_at': '2024-05-22T21:20:00+07:00',
#     'return_at': '2024-05-25T17:20:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 960,
#     'flight_number': 212}},
#   'SFO': {'2': {'airline': 'QR',
#     'departure_at': '2024-04-07T23:25:00+07:00',
#     'return_at': '2024-04-28T22:30:00-07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1367,
#     'flight_number': 841}},
#   'SGC': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-07T10:35:00+07:00',
#     'return_at': '2024-04-09T04:45:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 854,
#     'flight_number': 275}},
#   'SGN': {'1': {'airline': 'TR',
#     'departure_at': '2024-05-08T20:00:00+07:00',
#     'return_at': '2024-05-11T15:15:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 155,
#     'flight_number': 653}},
#   'SHA': {'1': {'airline': 'CZ',
#     'departure_at': '2024-05-20T23:30:00+07:00',
#     'return_at': '2024-05-26T11:50:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 185,
#     'flight_number': 6058}},
#   'SHE': {'1': {'airline': 'MU',
#     'departure_at': '2024-04-29T18:55:00+07:00',
#     'return_at': '2024-05-02T12:40:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 396,
#     'flight_number': 5094}},
#   'SHJ': {'0': {'airline': 'G9',
#     'departure_at': '2024-05-10T08:45:00+07:00',
#     'return_at': '2024-05-16T22:15:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 440,
#     'flight_number': 688}},
#   'SIN': {'0': {'airline': 'FD',
#     'departure_at': '2024-05-09T09:45:00+07:00',
#     'return_at': '2024-05-12T13:15:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 107,
#     'flight_number': 376}},
#   'SKD': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-12T10:35:00+07:00',
#     'return_at': '2024-04-17T07:20:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 837,
#     'flight_number': 275}},
#   'SSH': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-17T10:35:00+07:00',
#     'return_at': '2024-04-24T08:45:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 870,
#     'flight_number': 275}},
#   'SVX': {'2': {'airline': 'FM',
#     'departure_at': '2024-05-16T00:20:00+07:00',
#     'return_at': '2024-05-17T12:00:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 579,
#     'flight_number': 8618}},
#   'SYD': {'1': {'airline': 'AK',
#     'departure_at': '2024-05-08T19:20:00+07:00',
#     'return_at': '2024-05-15T09:45:00+10:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 343,
#     'flight_number': 821}},
#   'SYX': {'1': {'airline': 'HX',
#     'departure_at': '2024-06-20T21:00:00+07:00',
#     'return_at': '2024-06-30T13:45:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 271,
#     'flight_number': 742}},
#   'SZX': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-01T18:30:00+07:00',
#     'return_at': '2024-05-04T20:55:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 259,
#     'flight_number': 3022}},
#   'TAS': {'3': {'airline': 'AK',
#     'departure_at': '2024-04-27T21:40:00+07:00',
#     'return_at': '2024-05-10T23:30:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 653,
#     'flight_number': 823}},
#   'TBS': {'2': {'airline': 'OV',
#     'departure_at': '2024-04-26T23:15:00+07:00',
#     'return_at': '2024-05-04T19:30:00+04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 677,
#     'flight_number': 486}},
#   'TDX': {'1': {'airline': 'PG',
#     'departure_at': '2024-05-16T10:20:00+07:00',
#     'return_at': '2024-05-23T13:10:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 212,
#     'flight_number': 272}},
#   'TGD': {'3': {'airline': '6E',
#     'departure_at': '2024-04-22T00:15:00+07:00',
#     'return_at': '2024-04-28T10:30:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 897,
#     'flight_number': 1912}},
#   'THS': {'1': {'airline': 'FD',
#     'departure_at': '2024-04-27T22:15:00+07:00',
#     'return_at': '2024-05-05T08:55:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 166,
#     'flight_number': 4113}},
#   'TIV': {'2': {'airline': 'MH',
#     'departure_at': '2024-06-27T14:05:00+07:00',
#     'return_at': '2024-07-01T17:45:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 866,
#     'flight_number': 795}},
#   'TJM': {'2': {'airline': '3U',
#     'departure_at': '2024-05-23T19:30:00+07:00',
#     'return_at': '2024-05-29T06:55:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 792,
#     'flight_number': 3932}},
#   'TLL': {'2': {'airline': 'HO',
#     'departure_at': '2024-04-04T23:30:00+07:00',
#     'return_at': '2024-04-21T06:05:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1014,
#     'flight_number': 1370}},
#   'TLV': {'2': {'airline': 'PG',
#     'departure_at': '2024-05-27T21:55:00+07:00',
#     'return_at': '2024-06-06T14:45:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 687,
#     'flight_number': 280}},
#   'TNR': {'2': {'airline': 'PG',
#     'departure_at': '2024-05-01T19:10:00+07:00',
#     'return_at': '2024-05-16T14:50:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1220,
#     'flight_number': 278}},
#   'TOF': {'2': {'airline': 'SU',
#     'departure_at': '2024-04-18T10:35:00+07:00',
#     'return_at': '2024-04-20T11:25:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 875,
#     'flight_number': 275}},
#   'TPA': {'4': {'airline': 'VZ',
#     'departure_at': '2024-04-12T07:30:00+07:00',
#     'return_at': '2024-04-27T14:45:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1634,
#     'flight_number': 317}},
#   'TPE': {'1': {'airline': 'HX',
#     'departure_at': '2024-04-21T21:00:00+07:00',
#     'return_at': '2024-04-24T00:10:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 263,
#     'flight_number': 742}},
#   'TRV': {'1': {'airline': 'AK',
#     'departure_at': '2024-04-30T21:40:00+07:00',
#     'return_at': '2024-05-30T00:25:00+05:30',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 248,
#     'flight_number': 823}},
#   'TYO': {'1': {'airline': 'HX',
#     'departure_at': '2024-05-08T21:00:00+07:00',
#     'return_at': '2024-05-11T13:25:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 325,
#     'flight_number': 742}},
#   'UBP': {'1': {'airline': 'VZ',
#     'departure_at': '2024-04-22T07:30:00+07:00',
#     'return_at': '2024-04-22T19:35:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 160,
#     'flight_number': 317}},
#   'UFA': {'1': {'airline': 'G9',
#     'departure_at': '2024-05-05T08:45:00+07:00',
#     'return_at': '2024-05-26T01:30:00+05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 768,
#     'flight_number': 688}},
#   'UIH': {'2': {'airline': 'AK',
#     'departure_at': '2024-04-05T21:40:00+07:00',
#     'return_at': '2024-04-08T09:15:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 410,
#     'flight_number': 823}},
#   'UIO': {'2': {'airline': 'MH',
#     'departure_at': '2024-05-07T10:30:00+07:00',
#     'return_at': '2024-05-17T15:45:00-05:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 2082,
#     'flight_number': 787}},
#   'URT': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-16T09:30:00+07:00',
#     'return_at': '2024-06-07T11:35:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 121,
#     'flight_number': 3030}},
#   'USM': {'0': {'airline': 'PG',
#     'departure_at': '2024-06-10T13:00:00+07:00',
#     'return_at': '2024-06-20T14:30:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 113,
#     'flight_number': 254}},
#   'USU': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-13T12:45:00+07:00',
#     'return_at': '2024-04-24T07:45:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 546,
#     'flight_number': 276}},
#   'UTP': {'0': {'airline': 'PG',
#     'departure_at': '2024-06-18T15:10:00+07:00',
#     'return_at': '2024-06-30T13:00:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 74,
#     'flight_number': 282}},
#   'UUS': {'3': {'airline': 'CZ',
#     'departure_at': '2024-06-06T23:15:00+07:00',
#     'return_at': '2024-06-20T21:35:00+11:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 789,
#     'flight_number': 6058}},
#   'VAR': {'3': {'airline': 'OV',
#     'departure_at': '2024-05-04T11:20:00+07:00',
#     'return_at': '2024-05-06T22:25:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1120,
#     'flight_number': 482}},
#   'VCA': {'2': {'airline': 'FD',
#     'departure_at': '2024-06-07T09:30:00+07:00',
#     'return_at': '2024-06-09T21:10:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 298,
#     'flight_number': 3030}},
#   'VLC': {'2': {'airline': 'TG',
#     'departure_at': '2024-05-02T19:40:00+07:00',
#     'return_at': '2024-05-24T18:55:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 885,
#     'flight_number': 218}},
#   'VOG': {'2': {'airline': 'CZ',
#     'departure_at': '2024-04-29T16:40:00+07:00',
#     'return_at': '2024-05-23T10:05:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 883,
#     'flight_number': 6064}},
#   'VRA': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-10T10:35:00+07:00',
#     'return_at': '2024-04-20T19:10:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1830,
#     'flight_number': 275}},
#   'VTE': {'1': {'airline': 'FD',
#     'departure_at': '2024-05-08T22:25:00+07:00',
#     'return_at': '2024-05-10T08:05:00+07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 195,
#     'flight_number': 3014}},
#   'VVO': {'2': {'airline': 'CZ',
#     'departure_at': '2024-05-28T23:30:00+07:00',
#     'return_at': '2024-06-27T03:10:00+10:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 593,
#     'flight_number': 6058}},
#   'WAS': {'1': {'airline': 'QR',
#     'departure_at': '2024-04-27T20:30:00+07:00',
#     'return_at': '2024-05-11T22:14:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1429,
#     'flight_number': 847}},
#   'WAW': {'2': {'airline': 'MU',
#     'departure_at': '2024-04-26T00:20:00+07:00',
#     'return_at': '2024-05-15T05:55:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 735,
#     'flight_number': 832}},
#   'WDH': {'2': {'airline': 'PG',
#     'departure_at': '2024-04-22T19:10:00+07:00',
#     'return_at': '2024-05-06T14:30:00+02:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1081,
#     'flight_number': 278}},
#   'WLG': {'2': {'airline': 'CX',
#     'departure_at': '2024-04-30T11:50:00+07:00',
#     'return_at': '2024-05-09T21:10:00+12:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 907,
#     'flight_number': 770}},
#   'YAO': {'2': {'airline': 'TG',
#     'departure_at': '2024-04-25T21:20:00+07:00',
#     'return_at': '2024-05-09T02:10:00+01:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1518,
#     'flight_number': 212}},
#   'YKS': {'1': {'airline': 'SU',
#     'departure_at': '2024-04-17T11:20:00+07:00',
#     'return_at': '2024-05-09T06:00:00+09:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 948,
#     'flight_number': 661}},
#   'YNJ': {'1': {'airline': 'CZ',
#     'departure_at': '2024-04-22T16:40:00+07:00',
#     'return_at': '2024-05-03T08:00:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 338,
#     'flight_number': 6064}},
#   'YOW': {'2': {'airline': 'EK',
#     'departure_at': '2024-04-04T23:55:00+07:00',
#     'return_at': '2024-04-14T19:30:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1877,
#     'flight_number': 397}},
#   'YTO': {'2': {'airline': 'QR',
#     'departure_at': '2024-06-11T20:30:00+07:00',
#     'return_at': '2024-07-11T17:55:00-04:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1312,
#     'flight_number': 847}},
#   'YVR': {'1': {'airline': '3K',
#     'departure_at': '2024-07-01T21:20:00+07:00',
#     'return_at': '2024-07-28T12:30:00-07:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 1043,
#     'flight_number': 538}},
#   'ZNZ': {'2': {'airline': 'EY',
#     'departure_at': '2024-06-11T08:55:00+07:00',
#     'return_at': '2024-06-22T17:45:00+03:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 920,
#     'flight_number': 433}},
#   'ZUH': {'1': {'airline': 'MU',
#     'departure_at': '2024-06-12T00:05:00+07:00',
#     'return_at': '2024-06-13T22:45:00+08:00',
#     'expires_at': '2024-04-04T14:57:37Z',
#     'price': 301,
#     'flight_number': 2082}}},
#  'currency': 'EUR',
#  'success': True}

# %% [markdown]
# JSON object will be converted into a `dict` type, which is the data structure in Python holding key value pairs. To access certain values, we just access them like a `dict`.

# %%
ticket_flight = ticket['data']['AER']['2']
print(ticket_flight)
# Out:
# {'airline': 'CA', 'departure_at': '2024-05-01T19:30:00+07:00', 'return_at': '2024-05-03T13:05:00+03:00', 'expires_at': '2024-04-04T14:57:37Z', 'price': 774, 'flight_number': 822}

# %%
for data in ticket_flight:
    for key, value in ticket_flight.items():
        print(key, value)
# Out:
# airline CA
# departure_at 2024-05-01T19:30:00+07:00
# return_at 2024-05-03T13:05:00+03:00
# expires_at 2024-04-04T14:57:37Z
# price 774
# flight_number 822
# airline CA
# departure_at 2024-05-01T19:30:00+07:00
# return_at 2024-05-03T13:05:00+03:00
# expires_at 2024-04-04T14:57:37Z
# price 774
# flight_number 822
# airline CA
# departure_at 2024-05-01T19:30:00+07:00
# return_at 2024-05-03T13:05:00+03:00
# expires_at 2024-04-04T14:57:37Z
# price 774
# flight_number 822
# airline CA
# departure_at 2024-05-01T19:30:00+07:00
# return_at 2024-05-03T13:05:00+03:00
# expires_at 2024-04-04T14:57:37Z
# price 774
# flight_number 822
# airline CA
# departure_at 2024-05-01T19:30:00+07:00
# return_at 2024-05-03T13:05:00+03:00
# expires_at 2024-04-04T14:57:37Z
# price 774
# flight_number 822
# airline CA
# departure_at 2024-05-01T19:30:00+07:00
# return_at 2024-05-03T13:05:00+03:00
# expires_at 2024-04-04T14:57:37Z
# price 774
# flight_number 822

# %% [markdown]
# Now it gets interesting, as we can put the values into a dataframe (more on dataframes later).

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\christian\appdata\local\pypoetry\cache\virtualenvs\data-science-project-ziygbzbm-py3.11\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

ticket_dic = ticket['data']
lst = []

for price in ticket_dic:
    lst.append(pd.DataFrame.from_dict(price['AER']['2'], orient='index').transpose())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 7
#       4 lst = []
#       6 for price in ticket_dic:
# ----> 7     lst.append(pd.DataFrame.from_dict(price['AER']['2'], orient='index').transpose())
#
# TypeError: string indices must be integers, not 'str'

# %%
df = pd.concat(lst).reset_index()

# %%
df
# Out:
#      index                      created              observed parameterId  \
# 0        0  2023-03-21T10:37:37.028471Z  2023-03-21T10:40:00Z    temp_dry
# 1        0  2023-03-21T10:27:33.526521Z  2023-03-21T10:30:00Z    temp_dry
# 2        0  2023-03-21T10:17:36.028622Z  2023-03-21T10:20:00Z    temp_dry
# 3        0  2023-03-21T10:07:33.032789Z  2023-03-21T10:10:00Z    temp_dry
# 4        0  2023-03-21T09:57:32.027162Z  2023-03-21T10:00:00Z    temp_dry
# ..     ...                          ...                   ...         ...
# 139      0  2023-03-20T11:27:38.437213Z  2023-03-20T11:30:00Z    temp_dry
# 140      0  2023-03-20T11:18:08.438698Z  2023-03-20T11:20:00Z    temp_dry
# 141      0  2023-03-20T11:07:32.436279Z  2023-03-20T11:10:00Z    temp_dry
# 142      0  2023-03-20T10:57:32.936988Z  2023-03-20T11:00:00Z    temp_dry
# 143      0  2023-03-20T10:47:36.936483Z  2023-03-20T10:50:00Z    temp_dry
#
#     stationId value
# 0       06074   4.9
# 1       06074   4.9
# 2       06074   4.7
# 3       06074   4.6
# 4       06074   4.4
# ..        ...   ...
# 139     06074   5.8
# 140     06074   5.9
# 141     06074   6.2
# 142     06074   6.4
# 143     06074   6.0
#
# [144 rows x 6 columns]

# %% [markdown]
# ### Use packages: Twitter API as an example

# %% [markdown]
# Many web servers have their own APIs ready to use. By using these convenient tools, we can get started right off following their documentations and examples without any manual efforts.
#
# We will be using <a href="https://apps.twitter.com/" target="_blank">Twitter API</a> as an example. We will first install this package as shown [here](https://python-twitter.readthedocs.io/en/latest/installation.html)

# %% [markdown]
# You have to register an account for Twitter Developer and register an app.
#
# - go to https://dev.twitter.com/ and get an app togther. <a href="https://python-twitter.readthedocs.io/en/latest/getting_started.html" target="_b lank">Here</a>'s a quick start on how you can do this.
#
# After obtaining *__consumer key__*, *__consumer secret__*, *__access token__*, and *__access token secret__*, you are ready to retrieve some data from Twitter!

# %% [markdown]
# I have created a .env file in my root folder in the following way:
#
# ```
# consumer_key = your_consumer_key
# consumer_secret = your_consumer_secret
# access_token = your_access_token
# access_secret = your_access_secret
# ```

# %%
# Read the keys and tokens into a dictionary
my_dict = {}

with open("../.env", "r") as f:
    for line in f:
        key,val = line.split('=')
        my_dict[key.strip()] = val.strip()

# %%
my_dict
# Out:
# {'api_key': '98ec120f-22ae-4c65-bee5-c7979ce58fe2',
#  'consumer_key': 'pxckjDmamJ3MFSB4zbfGsf81X',
#  'consumer_secret': 'C0c16vwne2UjhcNCW7gv0h2NfqpTDOG4IkYFc8ccpvTyjg6fRv',
#  'access_token': '966273572015624192-VUvEJelTQGTYQijFRJhvbPqz6IqVlLK',
#  'access_secret': 'GCjsYL7lfj54tedcnznjQMJmJv6WNo86t20h4QPK29f37'}

# %%
## load twitter package, which a well-written Python package for Twitter APIs
import twitter
api = twitter.Api(consumer_key=my_dict['consumer_key'],
                  consumer_secret=my_dict['consumer_secret'],                  
                  access_token_key=my_dict['access_token'],
                  access_token_secret=my_dict['access_secret'])

## check status
api.VerifyCredentials()
# Out:
# User(ID=966273572015624192, ScreenName=PetriBagger)

# %%
statuses = api.GetUserTimeline(screen_name="PetriBagger")
for s in statuses:
    print(s.text)
# Out:
# @BornsVilkar @trygfonden @sanne_lind @politiken Det er en temmelig frisk konklusion at smide ud i offentligheden ud… https://t.co/HlVxJuvuWg
# #kapacity testing Azure logic apps
# RT @JosephineFock: Stop den overvågning, helt uacceptabelt at vi fortsat overvåger os alle #dkpol #stoplogning https://t.co/aIFu18Y8hj
# Jeg håber flere vil ty til civil ulydighed og boykotte de nationale trivselsmålinger af vores børn. Det er forrykt… https://t.co/GAf4zIJIvF

# %%
statuses = api.GetUserTimeline(user_id="966273572015624192")
for s in statuses:
    print(s.created_at)
# Out:
# Tue May 05 18:12:25 +0000 2020
# Thu Oct 25 07:24:33 +0000 2018
# Sun Mar 18 20:51:56 +0000 2018
# Mon Mar 12 21:52:22 +0000 2018

# %%
friends = api.GetFriends()
for f in friends:
    print(f.name)
# Out:
# Jakob Sorgenfri Kjær
# SpeakerAllan
# AllanGravgaardMadsen
# Jeppe Søe
# Erik Lahm
# Nielbo
# Astrid Porsmose
# Thor Hampus Bank
# Kirsten Birgit
# Søren Bo Steendahl
# Carl Johannes Borris
# Morten H.J. Fenger
# Martin Ibsen

# %% [markdown]
# More interestingly, let's go get some tweets from Twitter. Let's try to search for tweets related to `gpt4` since 01/01/2023 in English.
# - See https://dev.twitter.com/rest/public/search for more informaiton on how to construct a query

# %%
results = api.GetSearch(
    raw_query="q=gpt4&src=typed_query&since=2023-01-01&lang=en")

# %%
len(results)
# Out:
# 15

# %%
print(results)
# Out:
# [Status(ID=1638131840908419074, ScreenName=JLLEWIS0000, Created=Tue Mar 21 10:54:00 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/Trw8nmEidZ\n\n  #airdrop #NFT $HEX $SUI… https://t.co/vwZ4krb2nR'), Status(ID=1638131839263993856, ScreenName=TrackierHQ, Created=Tue Mar 21 10:54:00 +0000 2023, Text="We tried creating ad copies for our Mobile Marketing Platform using @HubSpot's latest https://t.co/n2SMtwH2xQ. \n\nHe… https://t.co/tqJXvbthwT"), Status(ID=1638131830204542977, ScreenName=MehdiBahramii, Created=Tue Mar 21 10:53:57 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/tXrxXEYZ2C\n\n  #airdrop #NFT $ETH $GPT4… https://t.co/BjwonlFy69'), Status(ID=1638131814060683264, ScreenName=Breezy_Shawtey, Created=Tue Mar 21 10:53:54 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/3C0qXRsRX1\n\n  #airdrop #NFT $BNB $RDNT… https://t.co/WhJ1F4xdnW'), Status(ID=1638131785715404801, ScreenName=DatzRealDae, Created=Tue Mar 21 10:53:47 +0000 2023, Text='RT @inbox1402: $GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/9lwI4VcpO6\n\n  #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4 $SSV $ARB $…'), Status(ID=1638131783727284231, ScreenName=sbc111, Created=Tue Mar 21 10:53:46 +0000 2023, Text='ChatGPT-assisted diagnosis: Is the future suddenly here? | @statnews  \n#AI #ChatGPT #chatgpt4 #GPT4 #HealthTech… https://t.co/JThhbZF2nw'), Status(ID=1638131763980664833, ScreenName=avocatvo, Created=Tue Mar 21 10:53:42 +0000 2023, Text='Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥 \n\n👉https://t.co/xn0WlXa4yn\n\n  #airdrop #NFT… https://t.co/lstjt1CEos'), Status(ID=1638131706443227136, ScreenName=JovanCokleski, Created=Tue Mar 21 10:53:28 +0000 2023, Text='Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥 \n\n👉https://t.co/7sGNg3JqcT\n\n  #airdrop #NFT… https://t.co/EfRZ9uDgkH'), Status(ID=1638131606652358656, ScreenName=inbox1402, Created=Tue Mar 21 10:53:04 +0000 2023, Text='$GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/9lwI4VcpO6\n\n  #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4… https://t.co/cyxkz7cKfg'), Status(ID=1638131515845648385, ScreenName=jearachelle, Created=Tue Mar 21 10:52:43 +0000 2023, Text="#GPT4 has only been out a week, and it's already changing lives. Ape and use $GPT4 to fuck yourself🚀🚀 \n\n👉… https://t.co/gp0DCYPLzI"), Status(ID=1638131493162696705, ScreenName=camino_ss, Created=Tue Mar 21 10:52:37 +0000 2023, Text='RT @lexus69778802: GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/Edn5cr7wM4\n\n  #airdrop #NFT #crypto $CFX $IM…'), Status(ID=1638131458090094595, ScreenName=SMERKINATOR, Created=Tue Mar 21 10:52:29 +0000 2023, Text='$GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/iXg2FdX0iW\n\n  #airdrop #NFT $RDNT $GPT $FIL $SUI $APT… https://t.co/EMAy01jGjt'), Status(ID=1638131429627551745, ScreenName=RLadyzhensky, Created=Tue Mar 21 10:52:22 +0000 2023, Text='$GPT4 is the future of AI and #Crypto 🚀🚀🚀 \n\n👉https://t.co/OSyOWmjdvk\n\n  #airdrop #NFT $SHI $BONK #ChatGPT #AI $GPT4… https://t.co/CImFh5YzBO'), Status(ID=1638131408769015808, ScreenName=blacksheepsteem, Created=Tue Mar 21 10:52:17 +0000 2023, Text='@realKilovoltage @Scrypto_Lang @radixdlt Still early but inevitable i think. Such a great way to learn. With more c… https://t.co/HYIMZ2RBoN'), Status(ID=1638131399726346240, ScreenName=jpfreemon, Created=Tue Mar 21 10:52:15 +0000 2023, Text='GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾 \n\n👉https://t.co/2eqwW1wu3M\n\n  #airdrop #NFT #GPT4 $ETH… https://t.co/kA0cIxn2fH')]

# %%
from IPython.display import clear_output
for tw in results:
    print("%s. Tweeted by \033[41m%s\033[0m"%(tw.text, tw.user.screen_name))
# Out:
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/Trw8nmEidZ
#
#   #airdrop #NFT $HEX $SUI… https://t.co/vwZ4krb2nR. Tweeted by JLLEWIS0000
# We tried creating ad copies for our Mobile Marketing Platform using @HubSpot's latest https://t.co/n2SMtwH2xQ.
#
# He… https://t.co/tqJXvbthwT. Tweeted by TrackierHQ
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/tXrxXEYZ2C
#
#   #airdrop #NFT $ETH $GPT4… https://t.co/BjwonlFy69. Tweeted by MehdiBahramii
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/3C0qXRsRX1
#
#   #airdrop #NFT $BNB $RDNT… https://t.co/WhJ1F4xdnW. Tweeted by Breezy_Shawtey
# RT @inbox1402: $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/9lwI4VcpO6
#
#   #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4 $SSV $ARB $…. Tweeted by DatzRealDae
# ChatGPT-assisted diagnosis: Is the future suddenly here? | @statnews
# #AI #ChatGPT #chatgpt4 #GPT4 #HealthTech… https://t.co/JThhbZF2nw. Tweeted by sbc111
# Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥
#
# 👉https://t.co/xn0WlXa4yn
#
#   #airdrop #NFT… https://t.co/lstjt1CEos. Tweeted by avocatvo
# Just checked my portfolio and this #GPT4 is doing crazy numbers! 🔥🔥🔥
#
# 👉https://t.co/7sGNg3JqcT
#
#   #airdrop #NFT… https://t.co/EfRZ9uDgkH. Tweeted by JovanCokleski
# $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/9lwI4VcpO6
#
#   #airdrop #NFT $CFX #ChatGPT $EVMOS $GPT4… https://t.co/cyxkz7cKfg. Tweeted by inbox1402
# #GPT4 has only been out a week, and it's already changing lives. Ape and use $GPT4 to fuck yourself🚀🚀
#
# 👉… https://t.co/gp0DCYPLzI. Tweeted by jearachelle
# RT @lexus69778802: GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/Edn5cr7wM4
#
#   #airdrop #NFT #crypto $CFX $IM…. Tweeted by camino_ss
# $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/iXg2FdX0iW
#
#   #airdrop #NFT $RDNT $GPT $FIL $SUI $APT… https://t.co/EMAy01jGjt. Tweeted by SMERKINATOR
# $GPT4 is the future of AI and #Crypto 🚀🚀🚀
#
# 👉https://t.co/OSyOWmjdvk
#
#   #airdrop #NFT $SHI $BONK #ChatGPT #AI $GPT4… https://t.co/CImFh5YzBO. Tweeted by RLadyzhensky
# @realKilovoltage @Scrypto_Lang @radixdlt Still early but inevitable i think. Such a great way to learn. With more c… https://t.co/HYIMZ2RBoN. Tweeted by blacksheepsteem
# GM!☕️☀️  Glad to see $GPT4 is 10x now, and still pumping!🦾🦾
#
# 👉https://t.co/2eqwW1wu3M
#
#   #airdrop #NFT #GPT4 $ETH… https://t.co/kA0cIxn2fH. Tweeted by jpfreemon

# %% [markdown]
# I went through some examples of using APIs to get various types of data in Python. The last Twitter example is relatively superficial. There are other packages to twitter, [`tweepy`] package seems to be pretty popular as well: http://www.tweepy.org/

# %% [markdown]
# return to [overview](../00_overview.ipynb)
